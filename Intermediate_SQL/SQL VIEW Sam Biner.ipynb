# %% [markdown]
# Load SQL extension

# %%
# %load_ext sql

# %% [markdown]
# Connect to your AWS RDS sakila database

# %%
# %sql mysql://admin:letmeinpls@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/sakila

# %% [markdown]
# ### VIEW Syntax
#
# ```
# CREATE [OR REPLACE] VIEW view_name AS
#     SELECT columns
#     FROM tables
#     [WHERE conditions];
# ```

# %% [markdown]
# ## 1. Frequently used query
#
#
# Who are our active customers?
# Create a VIEW for our active customers. Return all columns.

# %%
# %%sql
# CREATE OR REPLACE VIEW active_customer AS
#     SELECT *
#     FROM customer c
#     WHERE c.active = 1;
# Out:
#  * mysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/sakila
# 0 rows affected.
# []

# %% [markdown]
# ### SELECT from the VIEW

# %%
# %%sql
# SELECT *
# FROM active_customer
# LIMIT 10;
# Out:
#  * mysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/sakila
# 10 rows affected.
# [(1, 1, 'MARY', 'SMITH', 'MARY.SMITH@sakilacustomer.org', 5, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (2, 1, 'PATRICIA', 'JOHNSON', 'PATRICIA.JOHNSON@sakilacustomer.org', 6, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (3, 1, 'LINDA', 'WILLIAMS', 'LINDA.WILLIAMS@sakilacustomer.org', 7, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (4, 2, 'BARBARA', 'JONES', 'BARBARA.JONES@sakilacustomer.org', 8, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (5, 1, 'ELIZABETH', 'BROWN', 'ELIZABETH.BROWN@sakilacustomer.org', 9, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (6, 2, 'JENNIFER', 'DAVIS', 'JENNIFER.DAVIS@sakilacustomer.org', 10, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (7, 1, 'MARIA', 'MILLER', 'MARIA.MILLER@sakilacustomer.org', 11, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (8, 2, 'SUSAN', 'WILSON', 'SUSAN.WILSON@sakilacustomer.org', 12, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (9, 2, 'MARGARET', 'MOORE', 'MARGARET.MOORE@sakilacustomer.org', 13, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (10, 1, 'DOROTHY', 'TAYLOR', 'DOROTHY.TAYLOR@sakilacustomer.org', 14, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20))]

# %% [markdown]
# ### VIEW naming convention
# Do not add a view/vw prefix/suffix to the VIEW name. VIEWS are commonly turned into tables at some point.
# Prevents application code updates:
# ```
# SELECT *
# FROM active_customer;
# ```
#
# versus
#
# ```
# SELECT *
# FROM view_active_customer;
# ```

# %% [markdown]
# ### List VIEWS

# %%
# %%sql
# SHOW FULL TABLES
# WHERE Table_type = 'VIEW';
# Out:
#  * mysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/sakila
# 3 rows affected.
# [('active_customer', 'VIEW'),
#  ('film_actor_genre', 'VIEW'),
#  ('sales_by_film_category', 'VIEW')]

# %% [markdown]
# ### Display the VIEW's definition

# %%
# %%sql
# SHOW CREATE VIEW active_customer;
# Out:
#  * mysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/sakila
# 1 rows affected.
# [('active_customer', 'CREATE ALGORITHM=UNDEFINED DEFINER=`admin`@`%` SQL SECURITY DEFINER VIEW `active_customer` AS select `c`.`customer_id` AS `customer_id`,`c`.`store_id ... (126 characters truncated) ... dress_id`,`c`.`active` AS `active`,`c`.`create_date` AS `create_date`,`c`.`last_update` AS `last_update` from `customer` `c` where (`c`.`active` = 1)', 'utf8mb4', 'utf8mb4_0900_ai_ci')]

# %% [markdown]
# ### 2. Data security
# Limit access to certain columns. Hide sensitive information.
#
# Only display the active customer's first name, last name, and email.
# Obscure the email to prevent malicious usage to look like this: MA\*\*\*\*\*.org.
# Replace the active_customer VIEW.

# %%
# %%sql
# CREATE OR REPLACE VIEW active_customer AS
#     SELECT first_name,
#         last_name,
#         CONCAT(LEFT(email, 2), '*****.', SUBSTRING_INDEX(email, '.', -1)) AS concealed_email
#     FROM customer c
#     WHERE c.active = 1;
# Out:
#  * mysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/sakila
# 0 rows affected.
# []

# %% [markdown]
# Verify the new VIEW definition.

# %%
# %%sql
# SELECT *
# FROM active_customer;
# Out:
#  * mysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/sakila
# 584 rows affected.
# [('MARY', 'SMITH', 'MA*****.org'),
#  ('PATRICIA', 'JOHNSON', 'PA*****.org'),
#  ('LINDA', 'WILLIAMS', 'LI*****.org'),
#  ('BARBARA', 'JONES', 'BA*****.org'),
#  ('ELIZABETH', 'BROWN', 'EL*****.org'),
#  ('JENNIFER', 'DAVIS', 'JE*****.org'),
#  ('MARIA', 'MILLER', 'MA*****.org'),
#  ('SUSAN', 'WILSON', 'SU*****.org'),
#  ('MARGARET', 'MOORE', 'MA*****.org'),
#  ('DOROTHY', 'TAYLOR', 'DO*****.org'),
#  ('LISA', 'ANDERSON', 'LI*****.org'),
#  ('NANCY', 'THOMAS', 'NA*****.org'),
#  ('KAREN', 'JACKSON', 'KA*****.org'),
#  ('BETTY', 'WHITE', 'BE*****.org'),
#  ('HELEN', 'HARRIS', 'HE*****.org'),
#  ('DONNA', 'THOMPSON', 'DO*****.org'),
#  ('CAROL', 'GARCIA', 'CA*****.org'),
#  ('RUTH', 'MARTINEZ', 'RU*****.org'),
#  ('SHARON', 'ROBINSON', 'SH*****.org'),
#  ('MICHELLE', 'CLARK', 'MI*****.org'),
#  ('LAURA', 'RODRIGUEZ', 'LA*****.org'),
#  ('SARAH', 'LEWIS', 'SA*****.org'),
#  ('KIMBERLY', 'LEE', 'KI*****.org'),
#  ('DEBORAH', 'WALKER', 'DE*****.org'),
#  ('JESSICA', 'HALL', 'JE*****.org'),
#  ('SHIRLEY', 'ALLEN', 'SH*****.org'),
#  ('CYNTHIA', 'YOUNG', 'CY*****.org'),
#  ('ANGELA', 'HERNANDEZ', 'AN*****.org'),
#  ('MELISSA', 'KING', 'ME*****.org'),
#  ('BRENDA', 'WRIGHT', 'BR*****.org'),
#  ('AMY', 'LOPEZ', 'AM*****.org'),
#  ('ANNA', 'HILL', 'AN*****.org'),
#  ('REBECCA', 'SCOTT', 'RE*****.org'),
#  ('VIRGINIA', 'GREEN', 'VI*****.org'),
#  ('KATHLEEN', 'ADAMS', 'KA*****.org'),
#  ('PAMELA', 'BAKER', 'PA*****.org'),
#  ('MARTHA', 'GONZALEZ', 'MA*****.org'),
#  ('DEBRA', 'NELSON', 'DE*****.org'),
#  ('AMANDA', 'CARTER', 'AM*****.org'),
#  ('STEPHANIE', 'MITCHELL', 'ST*****.org'),
#  ('CAROLYN', 'PEREZ', 'CA*****.org'),
#  ('CHRISTINE', 'ROBERTS', 'CH*****.org'),
#  ('MARIE', 'TURNER', 'MA*****.org'),
#  ('JANET', 'PHILLIPS', 'JA*****.org'),
#  ('CATHERINE', 'CAMPBELL', 'CA*****.org'),
#  ('FRANCES', 'PARKER', 'FR*****.org'),
#  ('ANN', 'EVANS', 'AN*****.org'),
#  ('JOYCE', 'EDWARDS', 'JO*****.org'),
#  ('DIANE', 'COLLINS', 'DI*****.org'),
#  ('ALICE', 'STEWART', 'AL*****.org'),
#  ('JULIE', 'SANCHEZ', 'JU*****.org'),
#  ('HEATHER', 'MORRIS', 'HE*****.org'),
#  ('TERESA', 'ROGERS', 'TE*****.org'),
#  ('DORIS', 'REED', 'DO*****.org'),
#  ('GLORIA', 'COOK', 'GL*****.org'),
#  ('EVELYN', 'MORGAN', 'EV*****.org'),
#  ('JEAN', 'BELL', 'JE*****.org'),
#  ('CHERYL', 'MURPHY', 'CH*****.org'),
#  ('MILDRED', 'BAILEY', 'MI*****.org'),
#  ('KATHERINE', 'RIVERA', 'KA*****.org'),
#  ('JOAN', 'COOPER', 'JO*****.org'),
#  ('ASHLEY', 'RICHARDSON', 'AS*****.org'),
#  ('ROSE', 'HOWARD', 'RO*****.org'),
#  ('JANICE', 'WARD', 'JA*****.org'),
#  ('KELLY', 'TORRES', 'KE*****.org'),
#  ('NICOLE', 'PETERSON', 'NI*****.org'),
#  ('JUDY', 'GRAY', 'JU*****.org'),
#  ('CHRISTINA', 'RAMIREZ', 'CH*****.org'),
#  ('KATHY', 'JAMES', 'KA*****.org'),
#  ('THERESA', 'WATSON', 'TH*****.org'),
#  ('BEVERLY', 'BROOKS', 'BE*****.org'),
#  ('DENISE', 'KELLY', 'DE*****.org'),
#  ('TAMMY', 'SANDERS', 'TA*****.org'),
#  ('IRENE', 'PRICE', 'IR*****.org'),
#  ('JANE', 'BENNETT', 'JA*****.org'),
#  ('LORI', 'WOOD', 'LO*****.org'),
#  ('RACHEL', 'BARNES', 'RA*****.org'),
#  ('MARILYN', 'ROSS', 'MA*****.org'),
#  ('ANDREA', 'HENDERSON', 'AN*****.org'),
#  ('KATHRYN', 'COLEMAN', 'KA*****.org'),
#  ('LOUISE', 'JENKINS', 'LO*****.org'),
#  ('SARA', 'PERRY', 'SA*****.org'),
#  ('ANNE', 'POWELL', 'AN*****.org'),
#  ('JACQUELINE', 'LONG', 'JA*****.org'),
#  ('WANDA', 'PATTERSON', 'WA*****.org'),
#  ('BONNIE', 'HUGHES', 'BO*****.org'),
#  ('JULIA', 'FLORES', 'JU*****.org'),
#  ('RUBY', 'WASHINGTON', 'RU*****.org'),
#  ('LOIS', 'BUTLER', 'LO*****.org'),
#  ('TINA', 'SIMMONS', 'TI*****.org'),
#  ('PHYLLIS', 'FOSTER', 'PH*****.org'),
#  ('NORMA', 'GONZALES', 'NO*****.org'),
#  ('PAULA', 'BRYANT', 'PA*****.org'),
#  ('DIANA', 'ALEXANDER', 'DI*****.org'),
#  ('ANNIE', 'RUSSELL', 'AN*****.org'),
#  ('LILLIAN', 'GRIFFIN', 'LI*****.org'),
#  ('EMILY', 'DIAZ', 'EM*****.org'),
#  ('ROBIN', 'HAYES', 'RO*****.org'),
#  ('PEGGY', 'MYERS', 'PE*****.org'),
#  ('CRYSTAL', 'FORD', 'CR*****.org'),
#  ('GLADYS', 'HAMILTON', 'GL*****.org'),
#  ('RITA', 'GRAHAM', 'RI*****.org'),
#  ('DAWN', 'SULLIVAN', 'DA*****.org'),
#  ('CONNIE', 'WALLACE', 'CO*****.org'),
#  ('FLORENCE', 'WOODS', 'FL*****.org'),
#  ('TRACY', 'COLE', 'TR*****.org'),
#  ('EDNA', 'WEST', 'ED*****.org'),
#  ('TIFFANY', 'JORDAN', 'TI*****.org'),
#  ('CARMEN', 'OWENS', 'CA*****.org'),
#  ('ROSA', 'REYNOLDS', 'RO*****.org'),
#  ('CINDY', 'FISHER', 'CI*****.org'),
#  ('GRACE', 'ELLIS', 'GR*****.org'),
#  ('WENDY', 'HARRISON', 'WE*****.org'),
#  ('VICTORIA', 'GIBSON', 'VI*****.org'),
#  ('EDITH', 'MCDONALD', 'ED*****.org'),
#  ('KIM', 'CRUZ', 'KI*****.org'),
#  ('SHERRY', 'MARSHALL', 'SH*****.org'),
#  ('SYLVIA', 'ORTIZ', 'SY*****.org'),
#  ('JOSEPHINE', 'GOMEZ', 'JO*****.org'),
#  ('THELMA', 'MURRAY', 'TH*****.org'),
#  ('SHANNON', 'FREEMAN', 'SH*****.org'),
#  ('ETHEL', 'WEBB', 'ET*****.org'),
#  ('ELLEN', 'SIMPSON', 'EL*****.org'),
#  ('ELAINE', 'STEVENS', 'EL*****.org'),
#  ('MARJORIE', 'TUCKER', 'MA*****.org'),
#  ('CARRIE', 'PORTER', 'CA*****.org'),
#  ('CHARLOTTE', 'HUNTER', 'CH*****.org'),
#  ('MONICA', 'HICKS', 'MO*****.org'),
#  ('ESTHER', 'CRAWFORD', 'ES*****.org'),
#  ('PAULINE', 'HENRY', 'PA*****.org'),
#  ('EMMA', 'BOYD', 'EM*****.org'),
#  ('JUANITA', 'MASON', 'JU*****.org'),
#  ('ANITA', 'MORALES', 'AN*****.org'),
#  ('RHONDA', 'KENNEDY', 'RH*****.org'),
#  ('HAZEL', 'WARREN', 'HA*****.org'),
#  ('AMBER', 'DIXON', 'AM*****.org'),
#  ('EVA', 'RAMOS', 'EV*****.org'),
#  ('DEBBIE', 'REYES', 'DE*****.org'),
#  ('APRIL', 'BURNS', 'AP*****.org'),
#  ('LESLIE', 'GORDON', 'LE*****.org'),
#  ('CLARA', 'SHAW', 'CL*****.org'),
#  ('LUCILLE', 'HOLMES', 'LU*****.org'),
#  ('JAMIE', 'RICE', 'JA*****.org'),
#  ('JOANNE', 'ROBERTSON', 'JO*****.org'),
#  ('ELEANOR', 'HUNT', 'EL*****.org'),
#  ('VALERIE', 'BLACK', 'VA*****.org'),
#  ('DANIELLE', 'DANIELS', 'DA*****.org'),
#  ('MEGAN', 'PALMER', 'ME*****.org'),
#  ('ALICIA', 'MILLS', 'AL*****.org'),
#  ('SUZANNE', 'NICHOLS', 'SU*****.org'),
#  ('MICHELE', 'GRANT', 'MI*****.org'),
#  ('GAIL', 'KNIGHT', 'GA*****.org'),
#  ('BERTHA', 'FERGUSON', 'BE*****.org'),
#  ('DARLENE', 'ROSE', 'DA*****.org'),
#  ('VERONICA', 'STONE', 'VE*****.org'),
#  ('JILL', 'HAWKINS', 'JI*****.org'),
#  ('ERIN', 'DUNN', 'ER*****.org'),
#  ('GERALDINE', 'PERKINS', 'GE*****.org'),
#  ('LAUREN', 'HUDSON', 'LA*****.org'),
#  ('CATHY', 'SPENCER', 'CA*****.org'),
#  ('JOANN', 'GARDNER', 'JO*****.org'),
#  ('LORRAINE', 'STEPHENS', 'LO*****.org'),
#  ('LYNN', 'PAYNE', 'LY*****.org'),
#  ('SALLY', 'PIERCE', 'SA*****.org'),
#  ('REGINA', 'BERRY', 'RE*****.org'),
#  ('BEATRICE', 'ARNOLD', 'BE*****.org'),
#  ('DOLORES', 'WAGNER', 'DO*****.org'),
#  ('BERNICE', 'WILLIS', 'BE*****.org'),
#  ('AUDREY', 'RAY', 'AU*****.org'),
#  ('YVONNE', 'WATKINS', 'YV*****.org'),
#  ('ANNETTE', 'OLSON', 'AN*****.org'),
#  ('JUNE', 'CARROLL', 'JU*****.org'),
#  ('SAMANTHA', 'DUNCAN', 'SA*****.org'),
#  ('MARION', 'SNYDER', 'MA*****.org'),
#  ('DANA', 'HART', 'DA*****.org'),
#  ('STACY', 'CUNNINGHAM', 'ST*****.org'),
#  ('ANA', 'BRADLEY', 'AN*****.org'),
#  ('RENEE', 'LANE', 'RE*****.org'),
#  ('IDA', 'ANDREWS', 'ID*****.org'),
#  ('VIVIAN', 'RUIZ', 'VI*****.org'),
#  ('ROBERTA', 'HARPER', 'RO*****.org'),
#  ('HOLLY', 'FOX', 'HO*****.org'),
#  ('BRITTANY', 'RILEY', 'BR*****.org'),
#  ('MELANIE', 'ARMSTRONG', 'ME*****.org'),
#  ('LORETTA', 'CARPENTER', 'LO*****.org'),
#  ('YOLANDA', 'WEAVER', 'YO*****.org'),
#  ('JEANETTE', 'GREENE', 'JE*****.org'),
#  ('LAURIE', 'LAWRENCE', 'LA*****.org'),
#  ('KATIE', 'ELLIOTT', 'KA*****.org'),
#  ('KRISTEN', 'CHAVEZ', 'KR*****.org'),
#  ('VANESSA', 'SIMS', 'VA*****.org'),
#  ('ALMA', 'AUSTIN', 'AL*****.org'),
#  ('SUE', 'PETERS', 'SU*****.org'),
#  ('ELSIE', 'KELLEY', 'EL*****.org'),
#  ('BETH', 'FRANKLIN', 'BE*****.org'),
#  ('JEANNE', 'LAWSON', 'JE*****.org'),
#  ('VICKI', 'FIELDS', 'VI*****.org'),
#  ('CARLA', 'GUTIERREZ', 'CA*****.org'),
#  ('TARA', 'RYAN', 'TA*****.org'),
#  ('ROSEMARY', 'SCHMIDT', 'RO*****.org'),
#  ('EILEEN', 'CARR', 'EI*****.org'),
#  ('TERRI', 'VASQUEZ', 'TE*****.org'),
#  ('GERTRUDE', 'CASTILLO', 'GE*****.org'),
#  ('LUCY', 'WHEELER', 'LU*****.org'),
#  ('TONYA', 'CHAPMAN', 'TO*****.org'),
#  ('ELLA', 'OLIVER', 'EL*****.org'),
#  ('STACEY', 'MONTGOMERY', 'ST*****.org'),
#  ('WILMA', 'RICHARDS', 'WI*****.org'),
#  ('GINA', 'WILLIAMSON', 'GI*****.org'),
#  ('KRISTIN', 'JOHNSTON', 'KR*****.org'),
#  ('JESSIE', 'BANKS', 'JE*****.org'),
#  ('NATALIE', 'MEYER', 'NA*****.org'),
#  ('AGNES', 'BISHOP', 'AG*****.org'),
#  ('VERA', 'MCCOY', 'VE*****.org'),
#  ('WILLIE', 'HOWELL', 'WI*****.org'),
#  ('CHARLENE', 'ALVAREZ', 'CH*****.org'),
#  ('BESSIE', 'MORRISON', 'BE*****.org'),
#  ('DELORES', 'HANSEN', 'DE*****.org'),
#  ('MELINDA', 'FERNANDEZ', 'ME*****.org'),
#  ('PEARL', 'GARZA', 'PE*****.org'),
#  ('ARLENE', 'HARVEY', 'AR*****.org'),
#  ('MAUREEN', 'LITTLE', 'MA*****.org'),
#  ('COLLEEN', 'BURTON', 'CO*****.org'),
#  ('ALLISON', 'STANLEY', 'AL*****.org'),
#  ('TAMARA', 'NGUYEN', 'TA*****.org'),
#  ('JOY', 'GEORGE', 'JO*****.org'),
#  ('GEORGIA', 'JACOBS', 'GE*****.org'),
#  ('CONSTANCE', 'REID', 'CO*****.org'),
#  ('LILLIE', 'KIM', 'LI*****.org'),
#  ('CLAUDIA', 'FULLER', 'CL*****.org'),
#  ('JACKIE', 'LYNCH', 'JA*****.org'),
#  ('MARCIA', 'DEAN', 'MA*****.org'),
#  ('TANYA', 'GILBERT', 'TA*****.org'),
#  ('NELLIE', 'GARRETT', 'NE*****.org'),
#  ('MINNIE', 'ROMERO', 'MI*****.org'),
#  ('MARLENE', 'WELCH', 'MA*****.org'),
#  ('GLENDA', 'FRAZIER', 'GL*****.org'),
#  ('LYDIA', 'BURKE', 'LY*****.org'),
#  ('VIOLA', 'HANSON', 'VI*****.org'),
#  ('COURTNEY', 'DAY', 'CO*****.org'),
#  ('MARIAN', 'MENDOZA', 'MA*****.org'),
#  ('STELLA', 'MORENO', 'ST*****.org'),
#  ('CAROLINE', 'BOWMAN', 'CA*****.org'),
#  ('DORA', 'MEDINA', 'DO*****.org'),
#  ('JO', 'FOWLER', 'JO*****.org'),
#  ('VICKIE', 'BREWER', 'VI*****.org'),
#  ('MATTIE', 'HOFFMAN', 'MA*****.org'),
#  ('TERRY', 'CARLSON', 'TE*****.org'),
#  ('MAXINE', 'SILVA', 'MA*****.org'),
#  ('IRMA', 'PEARSON', 'IR*****.org'),
#  ('MABEL', 'HOLLAND', 'MA*****.org'),
#  ('MARSHA', 'DOUGLAS', 'MA*****.org'),
#  ('MYRTLE', 'FLEMING', 'MY*****.org'),
#  ('LENA', 'JENSEN', 'LE*****.org'),
#  ('CHRISTY', 'VARGAS', 'CH*****.org'),
#  ('DEANNA', 'BYRD', 'DE*****.org'),
#  ('PATSY', 'DAVIDSON', 'PA*****.org'),
#  ('HILDA', 'HOPKINS', 'HI*****.org'),
#  ('GWENDOLYN', 'MAY', 'GW*****.org'),
#  ('JENNIE', 'TERRY', 'JE*****.org'),
#  ('NORA', 'HERRERA', 'NO*****.org'),
#  ('MARGIE', 'WADE', 'MA*****.org'),
#  ('NINA', 'SOTO', 'NI*****.org'),
#  ('CASSANDRA', 'WALTERS', 'CA*****.org'),
#  ('LEAH', 'CURTIS', 'LE*****.org'),
#  ('KAY', 'CALDWELL', 'KA*****.org'),
#  ('PRISCILLA', 'LOWE', 'PR*****.org'),
#  ('NAOMI', 'JENNINGS', 'NA*****.org'),
#  ('CAROLE', 'BARNETT', 'CA*****.org'),
#  ('BRANDY', 'GRAVES', 'BR*****.org'),
#  ('OLGA', 'JIMENEZ', 'OL*****.org'),
#  ('BILLIE', 'HORTON', 'BI*****.org'),
#  ('DIANNE', 'SHELTON', 'DI*****.org'),
#  ('TRACEY', 'BARRETT', 'TR*****.org'),
#  ('LEONA', 'OBRIEN', 'LE*****.org'),
#  ('JENNY', 'CASTRO', 'JE*****.org'),
#  ('FELICIA', 'SUTTON', 'FE*****.org'),
#  ('SONIA', 'GREGORY', 'SO*****.org'),
#  ('MIRIAM', 'MCKINNEY', 'MI*****.org'),
#  ('VELMA', 'LUCAS', 'VE*****.org'),
#  ('BECKY', 'MILES', 'BE*****.org'),
#  ('BOBBIE', 'CRAIG', 'BO*****.org'),
#  ('VIOLET', 'RODRIQUEZ', 'VI*****.org'),
#  ('KRISTINA', 'CHAMBERS', 'KR*****.org'),
#  ('TONI', 'HOLT', 'TO*****.org'),
#  ('MISTY', 'LAMBERT', 'MI*****.org'),
#  ('MAE', 'FLETCHER', 'MA*****.org'),
#  ('SHELLY', 'WATTS', 'SH*****.org'),
#  ('DAISY', 'BATES', 'DA*****.org'),
#  ('RAMONA', 'HALE', 'RA*****.org'),
#  ('SHERRI', 'RHODES', 'SH*****.org'),
#  ('ERIKA', 'PENA', 'ER*****.org'),
#  ('JAMES', 'GANNON', 'JA*****.org'),
#  ('JOHN', 'FARNSWORTH', 'JO*****.org'),
#  ('ROBERT', 'BAUGHMAN', 'RO*****.org'),
#  ('MICHAEL', 'SILVERMAN', 'MI*****.org'),
#  ('WILLIAM', 'SATTERFIELD', 'WI*****.org'),
#  ('DAVID', 'ROYAL', 'DA*****.org'),
#  ('RICHARD', 'MCCRARY', 'RI*****.org'),
#  ('CHARLES', 'KOWALSKI', 'CH*****.org'),
#  ('JOSEPH', 'JOY', 'JO*****.org'),
#  ('THOMAS', 'GRIGSBY', 'TH*****.org'),
#  ('CHRISTOPHER', 'GRECO', 'CH*****.org'),
#  ('DANIEL', 'CABRAL', 'DA*****.org'),
#  ('PAUL', 'TROUT', 'PA*****.org'),
#  ('MARK', 'RINEHART', 'MA*****.org'),
#  ('DONALD', 'MAHON', 'DO*****.org'),
#  ('GEORGE', 'LINTON', 'GE*****.org'),
#  ('STEVEN', 'CURLEY', 'ST*****.org'),
#  ('EDWARD', 'BAUGH', 'ED*****.org'),
#  ('BRIAN', 'WYMAN', 'BR*****.org'),
#  ('RONALD', 'WEINER', 'RO*****.org'),
#  ('ANTHONY', 'SCHWAB', 'AN*****.org'),
#  ('KEVIN', 'SCHULER', 'KE*****.org'),
#  ('JASON', 'MORRISSEY', 'JA*****.org'),
#  ('MATTHEW', 'MAHAN', 'MA*****.org'),
#  ('GARY', 'COY', 'GA*****.org'),
#  ('TIMOTHY', 'BUNN', 'TI*****.org'),
#  ('JOSE', 'ANDREW', 'JO*****.org'),
#  ('LARRY', 'THRASHER', 'LA*****.org'),
#  ('JEFFREY', 'SPEAR', 'JE*****.org'),
#  ('FRANK', 'WAGGONER', 'FR*****.org'),
#  ('SCOTT', 'SHELLEY', 'SC*****.org'),
#  ('ERIC', 'ROBERT', 'ER*****.org'),
#  ('STEPHEN', 'QUALLS', 'ST*****.org'),
#  ('ANDREW', 'PURDY', 'AN*****.org'),
#  ('RAYMOND', 'MCWHORTER', 'RA*****.org'),
#  ('GREGORY', 'MAULDIN', 'GR*****.org'),
#  ('JOSHUA', 'MARK', 'JO*****.org'),
#  ('JERRY', 'JORDON', 'JE*****.org'),
#  ('DENNIS', 'GILMAN', 'DE*****.org'),
#  ('WALTER', 'PERRYMAN', 'WA*****.org'),
#  ('PATRICK', 'NEWSOM', 'PA*****.org'),
#  ('PETER', 'MENARD', 'PE*****.org'),
#  ('HAROLD', 'MARTINO', 'HA*****.org'),
#  ('DOUGLAS', 'GRAF', 'DO*****.org'),
#  ('HENRY', 'BILLINGSLEY', 'HE*****.org'),
#  ('CARL', 'ARTIS', 'CA*****.org'),
#  ('ARTHUR', 'SIMPKINS', 'AR*****.org'),
#  ('RYAN', 'SALISBURY', 'RY*****.org'),
#  ('ROGER', 'QUINTANILLA', 'RO*****.org'),
#  ('JOE', 'GILLILAND', 'JO*****.org'),
#  ('JUAN', 'FRALEY', 'JU*****.org'),
#  ('JACK', 'FOUST', 'JA*****.org'),
#  ('ALBERT', 'CROUSE', 'AL*****.org'),
#  ('JONATHAN', 'SCARBOROUGH', 'JO*****.org'),
#  ('JUSTIN', 'NGO', 'JU*****.org'),
#  ('TERRY', 'GRISSOM', 'TE*****.org'),
#  ('GERALD', 'FULTZ', 'GE*****.org'),
#  ('KEITH', 'RICO', 'KE*****.org'),
#  ('SAMUEL', 'MARLOW', 'SA*****.org'),
#  ('WILLIE', 'MARKHAM', 'WI*****.org'),
#  ('RALPH', 'MADRIGAL', 'RA*****.org'),
#  ('LAWRENCE', 'LAWTON', 'LA*****.org'),
#  ('NICHOLAS', 'BARFIELD', 'NI*****.org'),
#  ('ROY', 'WHITING', 'RO*****.org'),
#  ('BENJAMIN', 'VARNEY', 'BE*****.org'),
#  ('BRUCE', 'SCHWARZ', 'BR*****.org'),
#  ('BRANDON', 'HUEY', 'BR*****.org'),
#  ('ADAM', 'GOOCH', 'AD*****.org'),
#  ('FRED', 'WHEAT', 'FR*****.org'),
#  ('WAYNE', 'TRUONG', 'WA*****.org'),
#  ('BILLY', 'POULIN', 'BI*****.org'),
#  ('STEVE', 'MACKENZIE', 'ST*****.org'),
#  ('LOUIS', 'LEONE', 'LO*****.org'),
#  ('JEREMY', 'HURTADO', 'JE*****.org'),
#  ('AARON', 'SELBY', 'AA*****.org'),
#  ('RANDY', 'GAITHER', 'RA*****.org'),
#  ('HOWARD', 'FORTNER', 'HO*****.org'),
#  ('EUGENE', 'CULPEPPER', 'EU*****.org'),
#  ('CARLOS', 'COUGHLIN', 'CA*****.org'),
#  ('RUSSELL', 'BRINSON', 'RU*****.org'),
#  ('BOBBY', 'BOUDREAU', 'BO*****.org'),
#  ('VICTOR', 'BARKLEY', 'VI*****.org'),
#  ('MARTIN', 'BALES', 'MA*****.org'),
#  ('ERNEST', 'STEPP', 'ER*****.org'),
#  ('PHILLIP', 'HOLM', 'PH*****.org'),
#  ('TODD', 'TAN', 'TO*****.org'),
#  ('JESSE', 'SCHILLING', 'JE*****.org'),
#  ('CRAIG', 'MORRELL', 'CR*****.org'),
#  ('ALAN', 'KAHN', 'AL*****.org'),
#  ('SHAWN', 'HEATON', 'SH*****.org'),
#  ('CLARENCE', 'GAMEZ', 'CL*****.org'),
#  ('SEAN', 'DOUGLASS', 'SE*****.org'),
#  ('PHILIP', 'CAUSEY', 'PH*****.org'),
#  ('CHRIS', 'BROTHERS', 'CH*****.org'),
#  ('JOHNNY', 'TURPIN', 'JO*****.org'),
#  ('EARL', 'SHANKS', 'EA*****.org'),
#  ('JIMMY', 'SCHRADER', 'JI*****.org'),
#  ('ANTONIO', 'MEEK', 'AN*****.org'),
#  ('DANNY', 'ISOM', 'DA*****.org'),
#  ('BRYAN', 'HARDISON', 'BR*****.org'),
#  ('TONY', 'CARRANZA', 'TO*****.org'),
#  ('LUIS', 'YANEZ', 'LU*****.org'),
#  ('MIKE', 'WAY', 'MI*****.org'),
#  ('STANLEY', 'SCROGGINS', 'ST*****.org'),
#  ('LEONARD', 'SCHOFIELD', 'LE*****.org'),
#  ('DALE', 'RATCLIFF', 'DA*****.org'),
#  ('MANUEL', 'MURRELL', 'MA*****.org'),
#  ('RODNEY', 'MOELLER', 'RO*****.org'),
#  ('CURTIS', 'IRBY', 'CU*****.org'),
#  ('NORMAN', 'CURRIER', 'NO*****.org'),
#  ('ALLEN', 'BUTTERFIELD', 'AL*****.org'),
#  ('MARVIN', 'YEE', 'MA*****.org'),
#  ('VINCENT', 'RALSTON', 'VI*****.org'),
#  ('GLENN', 'PULLEN', 'GL*****.org'),
#  ('JEFFERY', 'PINSON', 'JE*****.org'),
#  ('TRAVIS', 'ESTEP', 'TR*****.org'),
#  ('JEFF', 'EAST', 'JE*****.org'),
#  ('CHAD', 'CARBONE', 'CH*****.org'),
#  ('JACOB', 'LANCE', 'JA*****.org'),
#  ('LEE', 'HAWKS', 'LE*****.org'),
#  ('MELVIN', 'ELLINGTON', 'ME*****.org'),
#  ('ALFRED', 'CASILLAS', 'AL*****.org'),
#  ('KYLE', 'SPURLOCK', 'KY*****.org'),
#  ('FRANCIS', 'SIKES', 'FR*****.org'),
#  ('BRADLEY', 'MOTLEY', 'BR*****.org'),
#  ('JESUS', 'MCCARTNEY', 'JE*****.org'),
#  ('HERBERT', 'KRUGER', 'HE*****.org'),
#  ('FREDERICK', 'ISBELL', 'FR*****.org'),
#  ('RAY', 'HOULE', 'RA*****.org'),
#  ('JOEL', 'FRANCISCO', 'JO*****.org'),
#  ('EDWIN', 'BURK', 'ED*****.org'),
#  ('DON', 'BONE', 'DO*****.org'),
#  ('EDDIE', 'TOMLIN', 'ED*****.org'),
#  ('RICKY', 'SHELBY', 'RI*****.org'),
#  ('TROY', 'QUIGLEY', 'TR*****.org'),
#  ('RANDALL', 'NEUMANN', 'RA*****.org'),
#  ('BARRY', 'LOVELACE', 'BA*****.org'),
#  ('ALEXANDER', 'FENNELL', 'AL*****.org'),
#  ('BERNARD', 'COLBY', 'BE*****.org'),
#  ('MARIO', 'CHEATHAM', 'MA*****.org'),
#  ('LEROY', 'BUSTAMANTE', 'LE*****.org'),
#  ('FRANCISCO', 'SKIDMORE', 'FR*****.org'),
#  ('MARCUS', 'HIDALGO', 'MA*****.org'),
#  ('MICHEAL', 'FORMAN', 'MI*****.org'),
#  ('CLIFFORD', 'BOWENS', 'CL*****.org'),
#  ('MIGUEL', 'BETANCOURT', 'MI*****.org'),
#  ('OSCAR', 'AQUINO', 'OS*****.org'),
#  ('JAY', 'ROBB', 'JA*****.org'),
#  ('JIM', 'REA', 'JI*****.org'),
#  ('TOM', 'MILNER', 'TO*****.org'),
#  ('CALVIN', 'MARTEL', 'CA*****.org'),
#  ('ALEX', 'GRESHAM', 'AL*****.org'),
#  ('JON', 'WILES', 'JO*****.org'),
#  ('RONNIE', 'RICKETTS', 'RO*****.org'),
#  ('BILL', 'GAVIN', 'BI*****.org'),
#  ('LLOYD', 'DOWD', 'LL*****.org'),
#  ('TOMMY', 'COLLAZO', 'TO*****.org'),
#  ('LEON', 'BOSTIC', 'LE*****.org'),
#  ('DEREK', 'BLAKELY', 'DE*****.org'),
#  ('WARREN', 'SHERROD', 'WA*****.org'),
#  ('DARRELL', 'POWER', 'DA*****.org'),
#  ('JEROME', 'KENYON', 'JE*****.org'),
#  ('FLOYD', 'GANDY', 'FL*****.org'),
#  ('LEO', 'EBERT', 'LE*****.org'),
#  ('ALVIN', 'DELOACH', 'AL*****.org'),
#  ('TIM', 'CARY', 'TI*****.org'),
#  ('WESLEY', 'BULL', 'WE*****.org'),
#  ('GORDON', 'ALLARD', 'GO*****.org'),
#  ('DEAN', 'SAUER', 'DE*****.org'),
#  ('GREG', 'ROBINS', 'GR*****.org'),
#  ('JORGE', 'OLIVARES', 'JO*****.org'),
#  ('DUSTIN', 'GILLETTE', 'DU*****.org'),
#  ('PEDRO', 'CHESTNUT', 'PE*****.org'),
#  ('DERRICK', 'BOURQUE', 'DE*****.org'),
#  ('DAN', 'PAINE', 'DA*****.org'),
#  ('LEWIS', 'LYMAN', 'LE*****.org'),
#  ('ZACHARY', 'HITE', 'ZA*****.org'),
#  ('COREY', 'HAUSER', 'CO*****.org'),
#  ('HERMAN', 'DEVORE', 'HE*****.org'),
#  ('VERNON', 'CHAPA', 'VE*****.org'),
#  ('ROBERTO', 'VU', 'RO*****.org'),
#  ('CLYDE', 'TOBIAS', 'CL*****.org'),
#  ('GLEN', 'TALBERT', 'GL*****.org'),
#  ('HECTOR', 'POINDEXTER', 'HE*****.org'),
#  ('SHANE', 'MILLARD', 'SH*****.org'),
#  ('RICARDO', 'MEADOR', 'RI*****.org'),
#  ('SAM', 'MCDUFFIE', 'SA*****.org'),
#  ('RICK', 'MATTOX', 'RI*****.org'),
#  ('LESTER', 'KRAUS', 'LE*****.org'),
#  ('BRENT', 'HARKINS', 'BR*****.org'),
#  ('RAMON', 'CHOATE', 'RA*****.org'),
#  ('CHARLIE', 'BESS', 'CH*****.org'),
#  ('TYLER', 'WREN', 'TY*****.org'),
#  ('GILBERT', 'SLEDGE', 'GI*****.org'),
#  ('GENE', 'SANBORN', 'GE*****.org'),
#  ('MARC', 'OUTLAW', 'MA*****.org'),
#  ('REGINALD', 'KINDER', 'RE*****.org'),
#  ('RUBEN', 'GEARY', 'RU*****.org'),
#  ('BRETT', 'CORNWELL', 'BR*****.org'),
#  ('ANGEL', 'BARCLAY', 'AN*****.org'),
#  ('NATHANIEL', 'ADAM', 'NA*****.org'),
#  ('RAFAEL', 'ABNEY', 'RA*****.org'),
#  ('LESLIE', 'SEWARD', 'LE*****.org'),
#  ('EDGAR', 'RHOADS', 'ED*****.org'),
#  ('MILTON', 'HOWLAND', 'MI*****.org'),
#  ('RAUL', 'FORTIER', 'RA*****.org'),
#  ('CHESTER', 'BENNER', 'CH*****.org'),
#  ('CECIL', 'VINES', 'CE*****.org'),
#  ('DUANE', 'TUBBS', 'DU*****.org'),
#  ('FRANKLIN', 'TROUTMAN', 'FR*****.org'),
#  ('ANDRE', 'RAPP', 'AN*****.org'),
#  ('ELMER', 'NOE', 'EL*****.org'),
#  ('BRAD', 'MCCURDY', 'BR*****.org'),
#  ('GABRIEL', 'HARDER', 'GA*****.org'),
#  ('RON', 'DELUCA', 'RO*****.org'),
#  ('MITCHELL', 'WESTMORELAND', 'MI*****.org'),
#  ('ROLAND', 'SOUTH', 'RO*****.org'),
#  ('ARNOLD', 'HAVENS', 'AR*****.org'),
#  ('HARVEY', 'GUAJARDO', 'HA*****.org'),
#  ('JARED', 'ELY', 'JA*****.org'),
#  ('ADRIAN', 'CLARY', 'AD*****.org'),
#  ('KARL', 'SEAL', 'KA*****.org'),
#  ('CORY', 'MEEHAN', 'CO*****.org'),
#  ('CLAUDE', 'HERZOG', 'CL*****.org'),
#  ('ERIK', 'GUILLEN', 'ER*****.org'),
#  ('DARRYL', 'ASHCRAFT', 'DA*****.org'),
#  ('JAMIE', 'WAUGH', 'JA*****.org'),
#  ('NEIL', 'RENNER', 'NE*****.org'),
#  ('JESSIE', 'MILAM', 'JE*****.org'),
#  ('JAVIER', 'ELROD', 'JA*****.org'),
#  ('FERNANDO', 'CHURCHILL', 'FE*****.org'),
#  ('CLINTON', 'BUFORD', 'CL*****.org'),
#  ('TED', 'BREAUX', 'TE*****.org'),
#  ('MATHEW', 'BOLIN', 'MA*****.org'),
#  ('TYRONE', 'ASHER', 'TY*****.org'),
#  ('DARREN', 'WINDHAM', 'DA*****.org'),
#  ('LONNIE', 'TIRADO', 'LO*****.org'),
#  ('LANCE', 'PEMBERTON', 'LA*****.org'),
#  ('CODY', 'NOLEN', 'CO*****.org'),
#  ('JULIO', 'NOLAND', 'JU*****.org'),
#  ('KELLY', 'KNOTT', 'KE*****.org'),
#  ('KURT', 'EMMONS', 'KU*****.org'),
#  ('ALLAN', 'CORNISH', 'AL*****.org'),
#  ('NELSON', 'CHRISTENSON', 'NE*****.org'),
#  ('GUY', 'BROWNLEE', 'GU*****.org'),
#  ('CLAYTON', 'BARBEE', 'CL*****.org'),
#  ('HUGH', 'WALDROP', 'HU*****.org'),
#  ('MAX', 'PITT', 'MA*****.org'),
#  ('DWAYNE', 'OLVERA', 'DW*****.org'),
#  ('DWIGHT', 'LOMBARDI', 'DW*****.org'),
#  ('ARMANDO', 'GRUBER', 'AR*****.org'),
#  ('FELIX', 'GAFFNEY', 'FE*****.org'),
#  ('EVERETT', 'BANDA', 'EV*****.org'),
#  ('JORDAN', 'ARCHULETA', 'JO*****.org'),
#  ('IAN', 'STILL', 'IA*****.org'),
#  ('WALLACE', 'SLONE', 'WA*****.org'),
#  ('KEN', 'PREWITT', 'KE*****.org'),
#  ('BOB', 'PFEIFFER', 'BO*****.org'),
#  ('JAIME', 'NETTLES', 'JA*****.org'),
#  ('CASEY', 'MENA', 'CA*****.org'),
#  ('ALFREDO', 'MCADAMS', 'AL*****.org'),
#  ('ALBERTO', 'HENNING', 'AL*****.org'),
#  ('DAVE', 'GARDINER', 'DA*****.org'),
#  ('IVAN', 'CROMWELL', 'IV*****.org'),
#  ('JOHNNIE', 'CHISHOLM', 'JO*****.org'),
#  ('SIDNEY', 'BURLESON', 'SI*****.org'),
#  ('BYRON', 'BOX', 'BY*****.org'),
#  ('JULIAN', 'VEST', 'JU*****.org'),
#  ('ISAAC', 'OGLESBY', 'IS*****.org'),
#  ('MORRIS', 'MCCARTER', 'MO*****.org'),
#  ('CLIFTON', 'MALCOLM', 'CL*****.org'),
#  ('WILLARD', 'LUMPKIN', 'WI*****.org'),
#  ('DARYL', 'LARUE', 'DA*****.org'),
#  ('ROSS', 'GREY', 'RO*****.org'),
#  ('VIRGIL', 'WOFFORD', 'VI*****.org'),
#  ('ANDY', 'VANHORN', 'AN*****.org'),
#  ('MARSHALL', 'THORN', 'MA*****.org'),
#  ('SALVADOR', 'TEEL', 'SA*****.org'),
#  ('PERRY', 'SWAFFORD', 'PE*****.org'),
#  ('KIRK', 'STCLAIR', 'KI*****.org'),
#  ('SERGIO', 'STANFIELD', 'SE*****.org'),
#  ('MARION', 'OCAMPO', 'MA*****.org'),
#  ('TRACY', 'HERRMANN', 'TR*****.org'),
#  ('SETH', 'HANNON', 'SE*****.org'),
#  ('KENT', 'ARSENAULT', 'KE*****.org'),
#  ('RENE', 'MCALISTER', 'RE*****.org'),
#  ('EDUARDO', 'HIATT', 'ED*****.org'),
#  ('TERRENCE', 'GUNDERSON', 'TE*****.org'),
#  ('ENRIQUE', 'FORSYTHE', 'EN*****.org'),
#  ('FREDDIE', 'DUGGAN', 'FR*****.org'),
#  ('WADE', 'DELVALLE', 'WA*****.org'),
#  ('AUSTIN', 'CINTRON', 'AU*****.org')]

# %% [markdown]
# Code the SQL to obscure the email to this format:
# MA\*\*\*\*\*.org

# %%
# %%sql
# SELECT email,
#     CONCAT(LEFT(email, 2), '*****.', SUBSTRING_INDEX(email, '.', -1)) AS concealed_email
# FROM customer
# WHERE active = 1;
# Out:
#  * mysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/sakila
# 584 rows affected.
# [('MARY.SMITH@sakilacustomer.org', 'MA*****.org'),
#  ('PATRICIA.JOHNSON@sakilacustomer.org', 'PA*****.org'),
#  ('LINDA.WILLIAMS@sakilacustomer.org', 'LI*****.org'),
#  ('BARBARA.JONES@sakilacustomer.org', 'BA*****.org'),
#  ('ELIZABETH.BROWN@sakilacustomer.org', 'EL*****.org'),
#  ('JENNIFER.DAVIS@sakilacustomer.org', 'JE*****.org'),
#  ('MARIA.MILLER@sakilacustomer.org', 'MA*****.org'),
#  ('SUSAN.WILSON@sakilacustomer.org', 'SU*****.org'),
#  ('MARGARET.MOORE@sakilacustomer.org', 'MA*****.org'),
#  ('DOROTHY.TAYLOR@sakilacustomer.org', 'DO*****.org'),
#  ('LISA.ANDERSON@sakilacustomer.org', 'LI*****.org'),
#  ('NANCY.THOMAS@sakilacustomer.org', 'NA*****.org'),
#  ('KAREN.JACKSON@sakilacustomer.org', 'KA*****.org'),
#  ('BETTY.WHITE@sakilacustomer.org', 'BE*****.org'),
#  ('HELEN.HARRIS@sakilacustomer.org', 'HE*****.org'),
#  ('DONNA.THOMPSON@sakilacustomer.org', 'DO*****.org'),
#  ('CAROL.GARCIA@sakilacustomer.org', 'CA*****.org'),
#  ('RUTH.MARTINEZ@sakilacustomer.org', 'RU*****.org'),
#  ('SHARON.ROBINSON@sakilacustomer.org', 'SH*****.org'),
#  ('MICHELLE.CLARK@sakilacustomer.org', 'MI*****.org'),
#  ('LAURA.RODRIGUEZ@sakilacustomer.org', 'LA*****.org'),
#  ('SARAH.LEWIS@sakilacustomer.org', 'SA*****.org'),
#  ('KIMBERLY.LEE@sakilacustomer.org', 'KI*****.org'),
#  ('DEBORAH.WALKER@sakilacustomer.org', 'DE*****.org'),
#  ('JESSICA.HALL@sakilacustomer.org', 'JE*****.org'),
#  ('SHIRLEY.ALLEN@sakilacustomer.org', 'SH*****.org'),
#  ('CYNTHIA.YOUNG@sakilacustomer.org', 'CY*****.org'),
#  ('ANGELA.HERNANDEZ@sakilacustomer.org', 'AN*****.org'),
#  ('MELISSA.KING@sakilacustomer.org', 'ME*****.org'),
#  ('BRENDA.WRIGHT@sakilacustomer.org', 'BR*****.org'),
#  ('AMY.LOPEZ@sakilacustomer.org', 'AM*****.org'),
#  ('ANNA.HILL@sakilacustomer.org', 'AN*****.org'),
#  ('REBECCA.SCOTT@sakilacustomer.org', 'RE*****.org'),
#  ('VIRGINIA.GREEN@sakilacustomer.org', 'VI*****.org'),
#  ('KATHLEEN.ADAMS@sakilacustomer.org', 'KA*****.org'),
#  ('PAMELA.BAKER@sakilacustomer.org', 'PA*****.org'),
#  ('MARTHA.GONZALEZ@sakilacustomer.org', 'MA*****.org'),
#  ('DEBRA.NELSON@sakilacustomer.org', 'DE*****.org'),
#  ('AMANDA.CARTER@sakilacustomer.org', 'AM*****.org'),
#  ('STEPHANIE.MITCHELL@sakilacustomer.org', 'ST*****.org'),
#  ('CAROLYN.PEREZ@sakilacustomer.org', 'CA*****.org'),
#  ('CHRISTINE.ROBERTS@sakilacustomer.org', 'CH*****.org'),
#  ('MARIE.TURNER@sakilacustomer.org', 'MA*****.org'),
#  ('JANET.PHILLIPS@sakilacustomer.org', 'JA*****.org'),
#  ('CATHERINE.CAMPBELL@sakilacustomer.org', 'CA*****.org'),
#  ('FRANCES.PARKER@sakilacustomer.org', 'FR*****.org'),
#  ('ANN.EVANS@sakilacustomer.org', 'AN*****.org'),
#  ('JOYCE.EDWARDS@sakilacustomer.org', 'JO*****.org'),
#  ('DIANE.COLLINS@sakilacustomer.org', 'DI*****.org'),
#  ('ALICE.STEWART@sakilacustomer.org', 'AL*****.org'),
#  ('JULIE.SANCHEZ@sakilacustomer.org', 'JU*****.org'),
#  ('HEATHER.MORRIS@sakilacustomer.org', 'HE*****.org'),
#  ('TERESA.ROGERS@sakilacustomer.org', 'TE*****.org'),
#  ('DORIS.REED@sakilacustomer.org', 'DO*****.org'),
#  ('GLORIA.COOK@sakilacustomer.org', 'GL*****.org'),
#  ('EVELYN.MORGAN@sakilacustomer.org', 'EV*****.org'),
#  ('JEAN.BELL@sakilacustomer.org', 'JE*****.org'),
#  ('CHERYL.MURPHY@sakilacustomer.org', 'CH*****.org'),
#  ('MILDRED.BAILEY@sakilacustomer.org', 'MI*****.org'),
#  ('KATHERINE.RIVERA@sakilacustomer.org', 'KA*****.org'),
#  ('JOAN.COOPER@sakilacustomer.org', 'JO*****.org'),
#  ('ASHLEY.RICHARDSON@sakilacustomer.org', 'AS*****.org'),
#  ('ROSE.HOWARD@sakilacustomer.org', 'RO*****.org'),
#  ('JANICE.WARD@sakilacustomer.org', 'JA*****.org'),
#  ('KELLY.TORRES@sakilacustomer.org', 'KE*****.org'),
#  ('NICOLE.PETERSON@sakilacustomer.org', 'NI*****.org'),
#  ('JUDY.GRAY@sakilacustomer.org', 'JU*****.org'),
#  ('CHRISTINA.RAMIREZ@sakilacustomer.org', 'CH*****.org'),
#  ('KATHY.JAMES@sakilacustomer.org', 'KA*****.org'),
#  ('THERESA.WATSON@sakilacustomer.org', 'TH*****.org'),
#  ('BEVERLY.BROOKS@sakilacustomer.org', 'BE*****.org'),
#  ('DENISE.KELLY@sakilacustomer.org', 'DE*****.org'),
#  ('TAMMY.SANDERS@sakilacustomer.org', 'TA*****.org'),
#  ('IRENE.PRICE@sakilacustomer.org', 'IR*****.org'),
#  ('JANE.BENNETT@sakilacustomer.org', 'JA*****.org'),
#  ('LORI.WOOD@sakilacustomer.org', 'LO*****.org'),
#  ('RACHEL.BARNES@sakilacustomer.org', 'RA*****.org'),
#  ('MARILYN.ROSS@sakilacustomer.org', 'MA*****.org'),
#  ('ANDREA.HENDERSON@sakilacustomer.org', 'AN*****.org'),
#  ('KATHRYN.COLEMAN@sakilacustomer.org', 'KA*****.org'),
#  ('LOUISE.JENKINS@sakilacustomer.org', 'LO*****.org'),
#  ('SARA.PERRY@sakilacustomer.org', 'SA*****.org'),
#  ('ANNE.POWELL@sakilacustomer.org', 'AN*****.org'),
#  ('JACQUELINE.LONG@sakilacustomer.org', 'JA*****.org'),
#  ('WANDA.PATTERSON@sakilacustomer.org', 'WA*****.org'),
#  ('BONNIE.HUGHES@sakilacustomer.org', 'BO*****.org'),
#  ('JULIA.FLORES@sakilacustomer.org', 'JU*****.org'),
#  ('RUBY.WASHINGTON@sakilacustomer.org', 'RU*****.org'),
#  ('LOIS.BUTLER@sakilacustomer.org', 'LO*****.org'),
#  ('TINA.SIMMONS@sakilacustomer.org', 'TI*****.org'),
#  ('PHYLLIS.FOSTER@sakilacustomer.org', 'PH*****.org'),
#  ('NORMA.GONZALES@sakilacustomer.org', 'NO*****.org'),
#  ('PAULA.BRYANT@sakilacustomer.org', 'PA*****.org'),
#  ('DIANA.ALEXANDER@sakilacustomer.org', 'DI*****.org'),
#  ('ANNIE.RUSSELL@sakilacustomer.org', 'AN*****.org'),
#  ('LILLIAN.GRIFFIN@sakilacustomer.org', 'LI*****.org'),
#  ('EMILY.DIAZ@sakilacustomer.org', 'EM*****.org'),
#  ('ROBIN.HAYES@sakilacustomer.org', 'RO*****.org'),
#  ('PEGGY.MYERS@sakilacustomer.org', 'PE*****.org'),
#  ('CRYSTAL.FORD@sakilacustomer.org', 'CR*****.org'),
#  ('GLADYS.HAMILTON@sakilacustomer.org', 'GL*****.org'),
#  ('RITA.GRAHAM@sakilacustomer.org', 'RI*****.org'),
#  ('DAWN.SULLIVAN@sakilacustomer.org', 'DA*****.org'),
#  ('CONNIE.WALLACE@sakilacustomer.org', 'CO*****.org'),
#  ('FLORENCE.WOODS@sakilacustomer.org', 'FL*****.org'),
#  ('TRACY.COLE@sakilacustomer.org', 'TR*****.org'),
#  ('EDNA.WEST@sakilacustomer.org', 'ED*****.org'),
#  ('TIFFANY.JORDAN@sakilacustomer.org', 'TI*****.org'),
#  ('CARMEN.OWENS@sakilacustomer.org', 'CA*****.org'),
#  ('ROSA.REYNOLDS@sakilacustomer.org', 'RO*****.org'),
#  ('CINDY.FISHER@sakilacustomer.org', 'CI*****.org'),
#  ('GRACE.ELLIS@sakilacustomer.org', 'GR*****.org'),
#  ('WENDY.HARRISON@sakilacustomer.org', 'WE*****.org'),
#  ('VICTORIA.GIBSON@sakilacustomer.org', 'VI*****.org'),
#  ('EDITH.MCDONALD@sakilacustomer.org', 'ED*****.org'),
#  ('KIM.CRUZ@sakilacustomer.org', 'KI*****.org'),
#  ('SHERRY.MARSHALL@sakilacustomer.org', 'SH*****.org'),
#  ('SYLVIA.ORTIZ@sakilacustomer.org', 'SY*****.org'),
#  ('JOSEPHINE.GOMEZ@sakilacustomer.org', 'JO*****.org'),
#  ('THELMA.MURRAY@sakilacustomer.org', 'TH*****.org'),
#  ('SHANNON.FREEMAN@sakilacustomer.org', 'SH*****.org'),
#  ('ETHEL.WEBB@sakilacustomer.org', 'ET*****.org'),
#  ('ELLEN.SIMPSON@sakilacustomer.org', 'EL*****.org'),
#  ('ELAINE.STEVENS@sakilacustomer.org', 'EL*****.org'),
#  ('MARJORIE.TUCKER@sakilacustomer.org', 'MA*****.org'),
#  ('CARRIE.PORTER@sakilacustomer.org', 'CA*****.org'),
#  ('CHARLOTTE.HUNTER@sakilacustomer.org', 'CH*****.org'),
#  ('MONICA.HICKS@sakilacustomer.org', 'MO*****.org'),
#  ('ESTHER.CRAWFORD@sakilacustomer.org', 'ES*****.org'),
#  ('PAULINE.HENRY@sakilacustomer.org', 'PA*****.org'),
#  ('EMMA.BOYD@sakilacustomer.org', 'EM*****.org'),
#  ('JUANITA.MASON@sakilacustomer.org', 'JU*****.org'),
#  ('ANITA.MORALES@sakilacustomer.org', 'AN*****.org'),
#  ('RHONDA.KENNEDY@sakilacustomer.org', 'RH*****.org'),
#  ('HAZEL.WARREN@sakilacustomer.org', 'HA*****.org'),
#  ('AMBER.DIXON@sakilacustomer.org', 'AM*****.org'),
#  ('EVA.RAMOS@sakilacustomer.org', 'EV*****.org'),
#  ('DEBBIE.REYES@sakilacustomer.org', 'DE*****.org'),
#  ('APRIL.BURNS@sakilacustomer.org', 'AP*****.org'),
#  ('LESLIE.GORDON@sakilacustomer.org', 'LE*****.org'),
#  ('CLARA.SHAW@sakilacustomer.org', 'CL*****.org'),
#  ('LUCILLE.HOLMES@sakilacustomer.org', 'LU*****.org'),
#  ('JAMIE.RICE@sakilacustomer.org', 'JA*****.org'),
#  ('JOANNE.ROBERTSON@sakilacustomer.org', 'JO*****.org'),
#  ('ELEANOR.HUNT@sakilacustomer.org', 'EL*****.org'),
#  ('VALERIE.BLACK@sakilacustomer.org', 'VA*****.org'),
#  ('DANIELLE.DANIELS@sakilacustomer.org', 'DA*****.org'),
#  ('MEGAN.PALMER@sakilacustomer.org', 'ME*****.org'),
#  ('ALICIA.MILLS@sakilacustomer.org', 'AL*****.org'),
#  ('SUZANNE.NICHOLS@sakilacustomer.org', 'SU*****.org'),
#  ('MICHELE.GRANT@sakilacustomer.org', 'MI*****.org'),
#  ('GAIL.KNIGHT@sakilacustomer.org', 'GA*****.org'),
#  ('BERTHA.FERGUSON@sakilacustomer.org', 'BE*****.org'),
#  ('DARLENE.ROSE@sakilacustomer.org', 'DA*****.org'),
#  ('VERONICA.STONE@sakilacustomer.org', 'VE*****.org'),
#  ('JILL.HAWKINS@sakilacustomer.org', 'JI*****.org'),
#  ('ERIN.DUNN@sakilacustomer.org', 'ER*****.org'),
#  ('GERALDINE.PERKINS@sakilacustomer.org', 'GE*****.org'),
#  ('LAUREN.HUDSON@sakilacustomer.org', 'LA*****.org'),
#  ('CATHY.SPENCER@sakilacustomer.org', 'CA*****.org'),
#  ('JOANN.GARDNER@sakilacustomer.org', 'JO*****.org'),
#  ('LORRAINE.STEPHENS@sakilacustomer.org', 'LO*****.org'),
#  ('LYNN.PAYNE@sakilacustomer.org', 'LY*****.org'),
#  ('SALLY.PIERCE@sakilacustomer.org', 'SA*****.org'),
#  ('REGINA.BERRY@sakilacustomer.org', 'RE*****.org'),
#  ('BEATRICE.ARNOLD@sakilacustomer.org', 'BE*****.org'),
#  ('DOLORES.WAGNER@sakilacustomer.org', 'DO*****.org'),
#  ('BERNICE.WILLIS@sakilacustomer.org', 'BE*****.org'),
#  ('AUDREY.RAY@sakilacustomer.org', 'AU*****.org'),
#  ('YVONNE.WATKINS@sakilacustomer.org', 'YV*****.org'),
#  ('ANNETTE.OLSON@sakilacustomer.org', 'AN*****.org'),
#  ('JUNE.CARROLL@sakilacustomer.org', 'JU*****.org'),
#  ('SAMANTHA.DUNCAN@sakilacustomer.org', 'SA*****.org'),
#  ('MARION.SNYDER@sakilacustomer.org', 'MA*****.org'),
#  ('DANA.HART@sakilacustomer.org', 'DA*****.org'),
#  ('STACY.CUNNINGHAM@sakilacustomer.org', 'ST*****.org'),
#  ('ANA.BRADLEY@sakilacustomer.org', 'AN*****.org'),
#  ('RENEE.LANE@sakilacustomer.org', 'RE*****.org'),
#  ('IDA.ANDREWS@sakilacustomer.org', 'ID*****.org'),
#  ('VIVIAN.RUIZ@sakilacustomer.org', 'VI*****.org'),
#  ('ROBERTA.HARPER@sakilacustomer.org', 'RO*****.org'),
#  ('HOLLY.FOX@sakilacustomer.org', 'HO*****.org'),
#  ('BRITTANY.RILEY@sakilacustomer.org', 'BR*****.org'),
#  ('MELANIE.ARMSTRONG@sakilacustomer.org', 'ME*****.org'),
#  ('LORETTA.CARPENTER@sakilacustomer.org', 'LO*****.org'),
#  ('YOLANDA.WEAVER@sakilacustomer.org', 'YO*****.org'),
#  ('JEANETTE.GREENE@sakilacustomer.org', 'JE*****.org'),
#  ('LAURIE.LAWRENCE@sakilacustomer.org', 'LA*****.org'),
#  ('KATIE.ELLIOTT@sakilacustomer.org', 'KA*****.org'),
#  ('KRISTEN.CHAVEZ@sakilacustomer.org', 'KR*****.org'),
#  ('VANESSA.SIMS@sakilacustomer.org', 'VA*****.org'),
#  ('ALMA.AUSTIN@sakilacustomer.org', 'AL*****.org'),
#  ('SUE.PETERS@sakilacustomer.org', 'SU*****.org'),
#  ('ELSIE.KELLEY@sakilacustomer.org', 'EL*****.org'),
#  ('BETH.FRANKLIN@sakilacustomer.org', 'BE*****.org'),
#  ('JEANNE.LAWSON@sakilacustomer.org', 'JE*****.org'),
#  ('VICKI.FIELDS@sakilacustomer.org', 'VI*****.org'),
#  ('CARLA.GUTIERREZ@sakilacustomer.org', 'CA*****.org'),
#  ('TARA.RYAN@sakilacustomer.org', 'TA*****.org'),
#  ('ROSEMARY.SCHMIDT@sakilacustomer.org', 'RO*****.org'),
#  ('EILEEN.CARR@sakilacustomer.org', 'EI*****.org'),
#  ('TERRI.VASQUEZ@sakilacustomer.org', 'TE*****.org'),
#  ('GERTRUDE.CASTILLO@sakilacustomer.org', 'GE*****.org'),
#  ('LUCY.WHEELER@sakilacustomer.org', 'LU*****.org'),
#  ('TONYA.CHAPMAN@sakilacustomer.org', 'TO*****.org'),
#  ('ELLA.OLIVER@sakilacustomer.org', 'EL*****.org'),
#  ('STACEY.MONTGOMERY@sakilacustomer.org', 'ST*****.org'),
#  ('WILMA.RICHARDS@sakilacustomer.org', 'WI*****.org'),
#  ('GINA.WILLIAMSON@sakilacustomer.org', 'GI*****.org'),
#  ('KRISTIN.JOHNSTON@sakilacustomer.org', 'KR*****.org'),
#  ('JESSIE.BANKS@sakilacustomer.org', 'JE*****.org'),
#  ('NATALIE.MEYER@sakilacustomer.org', 'NA*****.org'),
#  ('AGNES.BISHOP@sakilacustomer.org', 'AG*****.org'),
#  ('VERA.MCCOY@sakilacustomer.org', 'VE*****.org'),
#  ('WILLIE.HOWELL@sakilacustomer.org', 'WI*****.org'),
#  ('CHARLENE.ALVAREZ@sakilacustomer.org', 'CH*****.org'),
#  ('BESSIE.MORRISON@sakilacustomer.org', 'BE*****.org'),
#  ('DELORES.HANSEN@sakilacustomer.org', 'DE*****.org'),
#  ('MELINDA.FERNANDEZ@sakilacustomer.org', 'ME*****.org'),
#  ('PEARL.GARZA@sakilacustomer.org', 'PE*****.org'),
#  ('ARLENE.HARVEY@sakilacustomer.org', 'AR*****.org'),
#  ('MAUREEN.LITTLE@sakilacustomer.org', 'MA*****.org'),
#  ('COLLEEN.BURTON@sakilacustomer.org', 'CO*****.org'),
#  ('ALLISON.STANLEY@sakilacustomer.org', 'AL*****.org'),
#  ('TAMARA.NGUYEN@sakilacustomer.org', 'TA*****.org'),
#  ('JOY.GEORGE@sakilacustomer.org', 'JO*****.org'),
#  ('GEORGIA.JACOBS@sakilacustomer.org', 'GE*****.org'),
#  ('CONSTANCE.REID@sakilacustomer.org', 'CO*****.org'),
#  ('LILLIE.KIM@sakilacustomer.org', 'LI*****.org'),
#  ('CLAUDIA.FULLER@sakilacustomer.org', 'CL*****.org'),
#  ('JACKIE.LYNCH@sakilacustomer.org', 'JA*****.org'),
#  ('MARCIA.DEAN@sakilacustomer.org', 'MA*****.org'),
#  ('TANYA.GILBERT@sakilacustomer.org', 'TA*****.org'),
#  ('NELLIE.GARRETT@sakilacustomer.org', 'NE*****.org'),
#  ('MINNIE.ROMERO@sakilacustomer.org', 'MI*****.org'),
#  ('MARLENE.WELCH@sakilacustomer.org', 'MA*****.org'),
#  ('GLENDA.FRAZIER@sakilacustomer.org', 'GL*****.org'),
#  ('LYDIA.BURKE@sakilacustomer.org', 'LY*****.org'),
#  ('VIOLA.HANSON@sakilacustomer.org', 'VI*****.org'),
#  ('COURTNEY.DAY@sakilacustomer.org', 'CO*****.org'),
#  ('MARIAN.MENDOZA@sakilacustomer.org', 'MA*****.org'),
#  ('STELLA.MORENO@sakilacustomer.org', 'ST*****.org'),
#  ('CAROLINE.BOWMAN@sakilacustomer.org', 'CA*****.org'),
#  ('DORA.MEDINA@sakilacustomer.org', 'DO*****.org'),
#  ('JO.FOWLER@sakilacustomer.org', 'JO*****.org'),
#  ('VICKIE.BREWER@sakilacustomer.org', 'VI*****.org'),
#  ('MATTIE.HOFFMAN@sakilacustomer.org', 'MA*****.org'),
#  ('TERRY.CARLSON@sakilacustomer.org', 'TE*****.org'),
#  ('MAXINE.SILVA@sakilacustomer.org', 'MA*****.org'),
#  ('IRMA.PEARSON@sakilacustomer.org', 'IR*****.org'),
#  ('MABEL.HOLLAND@sakilacustomer.org', 'MA*****.org'),
#  ('MARSHA.DOUGLAS@sakilacustomer.org', 'MA*****.org'),
#  ('MYRTLE.FLEMING@sakilacustomer.org', 'MY*****.org'),
#  ('LENA.JENSEN@sakilacustomer.org', 'LE*****.org'),
#  ('CHRISTY.VARGAS@sakilacustomer.org', 'CH*****.org'),
#  ('DEANNA.BYRD@sakilacustomer.org', 'DE*****.org'),
#  ('PATSY.DAVIDSON@sakilacustomer.org', 'PA*****.org'),
#  ('HILDA.HOPKINS@sakilacustomer.org', 'HI*****.org'),
#  ('GWENDOLYN.MAY@sakilacustomer.org', 'GW*****.org'),
#  ('JENNIE.TERRY@sakilacustomer.org', 'JE*****.org'),
#  ('NORA.HERRERA@sakilacustomer.org', 'NO*****.org'),
#  ('MARGIE.WADE@sakilacustomer.org', 'MA*****.org'),
#  ('NINA.SOTO@sakilacustomer.org', 'NI*****.org'),
#  ('CASSANDRA.WALTERS@sakilacustomer.org', 'CA*****.org'),
#  ('LEAH.CURTIS@sakilacustomer.org', 'LE*****.org'),
#  ('KAY.CALDWELL@sakilacustomer.org', 'KA*****.org'),
#  ('PRISCILLA.LOWE@sakilacustomer.org', 'PR*****.org'),
#  ('NAOMI.JENNINGS@sakilacustomer.org', 'NA*****.org'),
#  ('CAROLE.BARNETT@sakilacustomer.org', 'CA*****.org'),
#  ('BRANDY.GRAVES@sakilacustomer.org', 'BR*****.org'),
#  ('OLGA.JIMENEZ@sakilacustomer.org', 'OL*****.org'),
#  ('BILLIE.HORTON@sakilacustomer.org', 'BI*****.org'),
#  ('DIANNE.SHELTON@sakilacustomer.org', 'DI*****.org'),
#  ('TRACEY.BARRETT@sakilacustomer.org', 'TR*****.org'),
#  ('LEONA.OBRIEN@sakilacustomer.org', 'LE*****.org'),
#  ('JENNY.CASTRO@sakilacustomer.org', 'JE*****.org'),
#  ('FELICIA.SUTTON@sakilacustomer.org', 'FE*****.org'),
#  ('SONIA.GREGORY@sakilacustomer.org', 'SO*****.org'),
#  ('MIRIAM.MCKINNEY@sakilacustomer.org', 'MI*****.org'),
#  ('VELMA.LUCAS@sakilacustomer.org', 'VE*****.org'),
#  ('BECKY.MILES@sakilacustomer.org', 'BE*****.org'),
#  ('BOBBIE.CRAIG@sakilacustomer.org', 'BO*****.org'),
#  ('VIOLET.RODRIQUEZ@sakilacustomer.org', 'VI*****.org'),
#  ('KRISTINA.CHAMBERS@sakilacustomer.org', 'KR*****.org'),
#  ('TONI.HOLT@sakilacustomer.org', 'TO*****.org'),
#  ('MISTY.LAMBERT@sakilacustomer.org', 'MI*****.org'),
#  ('MAE.FLETCHER@sakilacustomer.org', 'MA*****.org'),
#  ('SHELLY.WATTS@sakilacustomer.org', 'SH*****.org'),
#  ('DAISY.BATES@sakilacustomer.org', 'DA*****.org'),
#  ('RAMONA.HALE@sakilacustomer.org', 'RA*****.org'),
#  ('SHERRI.RHODES@sakilacustomer.org', 'SH*****.org'),
#  ('ERIKA.PENA@sakilacustomer.org', 'ER*****.org'),
#  ('JAMES.GANNON@sakilacustomer.org', 'JA*****.org'),
#  ('JOHN.FARNSWORTH@sakilacustomer.org', 'JO*****.org'),
#  ('ROBERT.BAUGHMAN@sakilacustomer.org', 'RO*****.org'),
#  ('MICHAEL.SILVERMAN@sakilacustomer.org', 'MI*****.org'),
#  ('WILLIAM.SATTERFIELD@sakilacustomer.org', 'WI*****.org'),
#  ('DAVID.ROYAL@sakilacustomer.org', 'DA*****.org'),
#  ('RICHARD.MCCRARY@sakilacustomer.org', 'RI*****.org'),
#  ('CHARLES.KOWALSKI@sakilacustomer.org', 'CH*****.org'),
#  ('JOSEPH.JOY@sakilacustomer.org', 'JO*****.org'),
#  ('THOMAS.GRIGSBY@sakilacustomer.org', 'TH*****.org'),
#  ('CHRISTOPHER.GRECO@sakilacustomer.org', 'CH*****.org'),
#  ('DANIEL.CABRAL@sakilacustomer.org', 'DA*****.org'),
#  ('PAUL.TROUT@sakilacustomer.org', 'PA*****.org'),
#  ('MARK.RINEHART@sakilacustomer.org', 'MA*****.org'),
#  ('DONALD.MAHON@sakilacustomer.org', 'DO*****.org'),
#  ('GEORGE.LINTON@sakilacustomer.org', 'GE*****.org'),
#  ('STEVEN.CURLEY@sakilacustomer.org', 'ST*****.org'),
#  ('EDWARD.BAUGH@sakilacustomer.org', 'ED*****.org'),
#  ('BRIAN.WYMAN@sakilacustomer.org', 'BR*****.org'),
#  ('RONALD.WEINER@sakilacustomer.org', 'RO*****.org'),
#  ('ANTHONY.SCHWAB@sakilacustomer.org', 'AN*****.org'),
#  ('KEVIN.SCHULER@sakilacustomer.org', 'KE*****.org'),
#  ('JASON.MORRISSEY@sakilacustomer.org', 'JA*****.org'),
#  ('MATTHEW.MAHAN@sakilacustomer.org', 'MA*****.org'),
#  ('GARY.COY@sakilacustomer.org', 'GA*****.org'),
#  ('TIMOTHY.BUNN@sakilacustomer.org', 'TI*****.org'),
#  ('JOSE.ANDREW@sakilacustomer.org', 'JO*****.org'),
#  ('LARRY.THRASHER@sakilacustomer.org', 'LA*****.org'),
#  ('JEFFREY.SPEAR@sakilacustomer.org', 'JE*****.org'),
#  ('FRANK.WAGGONER@sakilacustomer.org', 'FR*****.org'),
#  ('SCOTT.SHELLEY@sakilacustomer.org', 'SC*****.org'),
#  ('ERIC.ROBERT@sakilacustomer.org', 'ER*****.org'),
#  ('STEPHEN.QUALLS@sakilacustomer.org', 'ST*****.org'),
#  ('ANDREW.PURDY@sakilacustomer.org', 'AN*****.org'),
#  ('RAYMOND.MCWHORTER@sakilacustomer.org', 'RA*****.org'),
#  ('GREGORY.MAULDIN@sakilacustomer.org', 'GR*****.org'),
#  ('JOSHUA.MARK@sakilacustomer.org', 'JO*****.org'),
#  ('JERRY.JORDON@sakilacustomer.org', 'JE*****.org'),
#  ('DENNIS.GILMAN@sakilacustomer.org', 'DE*****.org'),
#  ('WALTER.PERRYMAN@sakilacustomer.org', 'WA*****.org'),
#  ('PATRICK.NEWSOM@sakilacustomer.org', 'PA*****.org'),
#  ('PETER.MENARD@sakilacustomer.org', 'PE*****.org'),
#  ('HAROLD.MARTINO@sakilacustomer.org', 'HA*****.org'),
#  ('DOUGLAS.GRAF@sakilacustomer.org', 'DO*****.org'),
#  ('HENRY.BILLINGSLEY@sakilacustomer.org', 'HE*****.org'),
#  ('CARL.ARTIS@sakilacustomer.org', 'CA*****.org'),
#  ('ARTHUR.SIMPKINS@sakilacustomer.org', 'AR*****.org'),
#  ('RYAN.SALISBURY@sakilacustomer.org', 'RY*****.org'),
#  ('ROGER.QUINTANILLA@sakilacustomer.org', 'RO*****.org'),
#  ('JOE.GILLILAND@sakilacustomer.org', 'JO*****.org'),
#  ('JUAN.FRALEY@sakilacustomer.org', 'JU*****.org'),
#  ('JACK.FOUST@sakilacustomer.org', 'JA*****.org'),
#  ('ALBERT.CROUSE@sakilacustomer.org', 'AL*****.org'),
#  ('JONATHAN.SCARBOROUGH@sakilacustomer.org', 'JO*****.org'),
#  ('JUSTIN.NGO@sakilacustomer.org', 'JU*****.org'),
#  ('TERRY.GRISSOM@sakilacustomer.org', 'TE*****.org'),
#  ('GERALD.FULTZ@sakilacustomer.org', 'GE*****.org'),
#  ('KEITH.RICO@sakilacustomer.org', 'KE*****.org'),
#  ('SAMUEL.MARLOW@sakilacustomer.org', 'SA*****.org'),
#  ('WILLIE.MARKHAM@sakilacustomer.org', 'WI*****.org'),
#  ('RALPH.MADRIGAL@sakilacustomer.org', 'RA*****.org'),
#  ('LAWRENCE.LAWTON@sakilacustomer.org', 'LA*****.org'),
#  ('NICHOLAS.BARFIELD@sakilacustomer.org', 'NI*****.org'),
#  ('ROY.WHITING@sakilacustomer.org', 'RO*****.org'),
#  ('BENJAMIN.VARNEY@sakilacustomer.org', 'BE*****.org'),
#  ('BRUCE.SCHWARZ@sakilacustomer.org', 'BR*****.org'),
#  ('BRANDON.HUEY@sakilacustomer.org', 'BR*****.org'),
#  ('ADAM.GOOCH@sakilacustomer.org', 'AD*****.org'),
#  ('FRED.WHEAT@sakilacustomer.org', 'FR*****.org'),
#  ('WAYNE.TRUONG@sakilacustomer.org', 'WA*****.org'),
#  ('BILLY.POULIN@sakilacustomer.org', 'BI*****.org'),
#  ('STEVE.MACKENZIE@sakilacustomer.org', 'ST*****.org'),
#  ('LOUIS.LEONE@sakilacustomer.org', 'LO*****.org'),
#  ('JEREMY.HURTADO@sakilacustomer.org', 'JE*****.org'),
#  ('AARON.SELBY@sakilacustomer.org', 'AA*****.org'),
#  ('RANDY.GAITHER@sakilacustomer.org', 'RA*****.org'),
#  ('HOWARD.FORTNER@sakilacustomer.org', 'HO*****.org'),
#  ('EUGENE.CULPEPPER@sakilacustomer.org', 'EU*****.org'),
#  ('CARLOS.COUGHLIN@sakilacustomer.org', 'CA*****.org'),
#  ('RUSSELL.BRINSON@sakilacustomer.org', 'RU*****.org'),
#  ('BOBBY.BOUDREAU@sakilacustomer.org', 'BO*****.org'),
#  ('VICTOR.BARKLEY@sakilacustomer.org', 'VI*****.org'),
#  ('MARTIN.BALES@sakilacustomer.org', 'MA*****.org'),
#  ('ERNEST.STEPP@sakilacustomer.org', 'ER*****.org'),
#  ('PHILLIP.HOLM@sakilacustomer.org', 'PH*****.org'),
#  ('TODD.TAN@sakilacustomer.org', 'TO*****.org'),
#  ('JESSE.SCHILLING@sakilacustomer.org', 'JE*****.org'),
#  ('CRAIG.MORRELL@sakilacustomer.org', 'CR*****.org'),
#  ('ALAN.KAHN@sakilacustomer.org', 'AL*****.org'),
#  ('SHAWN.HEATON@sakilacustomer.org', 'SH*****.org'),
#  ('CLARENCE.GAMEZ@sakilacustomer.org', 'CL*****.org'),
#  ('SEAN.DOUGLASS@sakilacustomer.org', 'SE*****.org'),
#  ('PHILIP.CAUSEY@sakilacustomer.org', 'PH*****.org'),
#  ('CHRIS.BROTHERS@sakilacustomer.org', 'CH*****.org'),
#  ('JOHNNY.TURPIN@sakilacustomer.org', 'JO*****.org'),
#  ('EARL.SHANKS@sakilacustomer.org', 'EA*****.org'),
#  ('JIMMY.SCHRADER@sakilacustomer.org', 'JI*****.org'),
#  ('ANTONIO.MEEK@sakilacustomer.org', 'AN*****.org'),
#  ('DANNY.ISOM@sakilacustomer.org', 'DA*****.org'),
#  ('BRYAN.HARDISON@sakilacustomer.org', 'BR*****.org'),
#  ('TONY.CARRANZA@sakilacustomer.org', 'TO*****.org'),
#  ('LUIS.YANEZ@sakilacustomer.org', 'LU*****.org'),
#  ('MIKE.WAY@sakilacustomer.org', 'MI*****.org'),
#  ('STANLEY.SCROGGINS@sakilacustomer.org', 'ST*****.org'),
#  ('LEONARD.SCHOFIELD@sakilacustomer.org', 'LE*****.org'),
#  ('DALE.RATCLIFF@sakilacustomer.org', 'DA*****.org'),
#  ('MANUEL.MURRELL@sakilacustomer.org', 'MA*****.org'),
#  ('RODNEY.MOELLER@sakilacustomer.org', 'RO*****.org'),
#  ('CURTIS.IRBY@sakilacustomer.org', 'CU*****.org'),
#  ('NORMAN.CURRIER@sakilacustomer.org', 'NO*****.org'),
#  ('ALLEN.BUTTERFIELD@sakilacustomer.org', 'AL*****.org'),
#  ('MARVIN.YEE@sakilacustomer.org', 'MA*****.org'),
#  ('VINCENT.RALSTON@sakilacustomer.org', 'VI*****.org'),
#  ('GLENN.PULLEN@sakilacustomer.org', 'GL*****.org'),
#  ('JEFFERY.PINSON@sakilacustomer.org', 'JE*****.org'),
#  ('TRAVIS.ESTEP@sakilacustomer.org', 'TR*****.org'),
#  ('JEFF.EAST@sakilacustomer.org', 'JE*****.org'),
#  ('CHAD.CARBONE@sakilacustomer.org', 'CH*****.org'),
#  ('JACOB.LANCE@sakilacustomer.org', 'JA*****.org'),
#  ('LEE.HAWKS@sakilacustomer.org', 'LE*****.org'),
#  ('MELVIN.ELLINGTON@sakilacustomer.org', 'ME*****.org'),
#  ('ALFRED.CASILLAS@sakilacustomer.org', 'AL*****.org'),
#  ('KYLE.SPURLOCK@sakilacustomer.org', 'KY*****.org'),
#  ('FRANCIS.SIKES@sakilacustomer.org', 'FR*****.org'),
#  ('BRADLEY.MOTLEY@sakilacustomer.org', 'BR*****.org'),
#  ('JESUS.MCCARTNEY@sakilacustomer.org', 'JE*****.org'),
#  ('HERBERT.KRUGER@sakilacustomer.org', 'HE*****.org'),
#  ('FREDERICK.ISBELL@sakilacustomer.org', 'FR*****.org'),
#  ('RAY.HOULE@sakilacustomer.org', 'RA*****.org'),
#  ('JOEL.FRANCISCO@sakilacustomer.org', 'JO*****.org'),
#  ('EDWIN.BURK@sakilacustomer.org', 'ED*****.org'),
#  ('DON.BONE@sakilacustomer.org', 'DO*****.org'),
#  ('EDDIE.TOMLIN@sakilacustomer.org', 'ED*****.org'),
#  ('RICKY.SHELBY@sakilacustomer.org', 'RI*****.org'),
#  ('TROY.QUIGLEY@sakilacustomer.org', 'TR*****.org'),
#  ('RANDALL.NEUMANN@sakilacustomer.org', 'RA*****.org'),
#  ('BARRY.LOVELACE@sakilacustomer.org', 'BA*****.org'),
#  ('ALEXANDER.FENNELL@sakilacustomer.org', 'AL*****.org'),
#  ('BERNARD.COLBY@sakilacustomer.org', 'BE*****.org'),
#  ('MARIO.CHEATHAM@sakilacustomer.org', 'MA*****.org'),
#  ('LEROY.BUSTAMANTE@sakilacustomer.org', 'LE*****.org'),
#  ('FRANCISCO.SKIDMORE@sakilacustomer.org', 'FR*****.org'),
#  ('MARCUS.HIDALGO@sakilacustomer.org', 'MA*****.org'),
#  ('MICHEAL.FORMAN@sakilacustomer.org', 'MI*****.org'),
#  ('CLIFFORD.BOWENS@sakilacustomer.org', 'CL*****.org'),
#  ('MIGUEL.BETANCOURT@sakilacustomer.org', 'MI*****.org'),
#  ('OSCAR.AQUINO@sakilacustomer.org', 'OS*****.org'),
#  ('JAY.ROBB@sakilacustomer.org', 'JA*****.org'),
#  ('JIM.REA@sakilacustomer.org', 'JI*****.org'),
#  ('TOM.MILNER@sakilacustomer.org', 'TO*****.org'),
#  ('CALVIN.MARTEL@sakilacustomer.org', 'CA*****.org'),
#  ('ALEX.GRESHAM@sakilacustomer.org', 'AL*****.org'),
#  ('JON.WILES@sakilacustomer.org', 'JO*****.org'),
#  ('RONNIE.RICKETTS@sakilacustomer.org', 'RO*****.org'),
#  ('BILL.GAVIN@sakilacustomer.org', 'BI*****.org'),
#  ('LLOYD.DOWD@sakilacustomer.org', 'LL*****.org'),
#  ('TOMMY.COLLAZO@sakilacustomer.org', 'TO*****.org'),
#  ('LEON.BOSTIC@sakilacustomer.org', 'LE*****.org'),
#  ('DEREK.BLAKELY@sakilacustomer.org', 'DE*****.org'),
#  ('WARREN.SHERROD@sakilacustomer.org', 'WA*****.org'),
#  ('DARRELL.POWER@sakilacustomer.org', 'DA*****.org'),
#  ('JEROME.KENYON@sakilacustomer.org', 'JE*****.org'),
#  ('FLOYD.GANDY@sakilacustomer.org', 'FL*****.org'),
#  ('LEO.EBERT@sakilacustomer.org', 'LE*****.org'),
#  ('ALVIN.DELOACH@sakilacustomer.org', 'AL*****.org'),
#  ('TIM.CARY@sakilacustomer.org', 'TI*****.org'),
#  ('WESLEY.BULL@sakilacustomer.org', 'WE*****.org'),
#  ('GORDON.ALLARD@sakilacustomer.org', 'GO*****.org'),
#  ('DEAN.SAUER@sakilacustomer.org', 'DE*****.org'),
#  ('GREG.ROBINS@sakilacustomer.org', 'GR*****.org'),
#  ('JORGE.OLIVARES@sakilacustomer.org', 'JO*****.org'),
#  ('DUSTIN.GILLETTE@sakilacustomer.org', 'DU*****.org'),
#  ('PEDRO.CHESTNUT@sakilacustomer.org', 'PE*****.org'),
#  ('DERRICK.BOURQUE@sakilacustomer.org', 'DE*****.org'),
#  ('DAN.PAINE@sakilacustomer.org', 'DA*****.org'),
#  ('LEWIS.LYMAN@sakilacustomer.org', 'LE*****.org'),
#  ('ZACHARY.HITE@sakilacustomer.org', 'ZA*****.org'),
#  ('COREY.HAUSER@sakilacustomer.org', 'CO*****.org'),
#  ('HERMAN.DEVORE@sakilacustomer.org', 'HE*****.org'),
#  ('VERNON.CHAPA@sakilacustomer.org', 'VE*****.org'),
#  ('ROBERTO.VU@sakilacustomer.org', 'RO*****.org'),
#  ('CLYDE.TOBIAS@sakilacustomer.org', 'CL*****.org'),
#  ('GLEN.TALBERT@sakilacustomer.org', 'GL*****.org'),
#  ('HECTOR.POINDEXTER@sakilacustomer.org', 'HE*****.org'),
#  ('SHANE.MILLARD@sakilacustomer.org', 'SH*****.org'),
#  ('RICARDO.MEADOR@sakilacustomer.org', 'RI*****.org'),
#  ('SAM.MCDUFFIE@sakilacustomer.org', 'SA*****.org'),
#  ('RICK.MATTOX@sakilacustomer.org', 'RI*****.org'),
#  ('LESTER.KRAUS@sakilacustomer.org', 'LE*****.org'),
#  ('BRENT.HARKINS@sakilacustomer.org', 'BR*****.org'),
#  ('RAMON.CHOATE@sakilacustomer.org', 'RA*****.org'),
#  ('CHARLIE.BESS@sakilacustomer.org', 'CH*****.org'),
#  ('TYLER.WREN@sakilacustomer.org', 'TY*****.org'),
#  ('GILBERT.SLEDGE@sakilacustomer.org', 'GI*****.org'),
#  ('GENE.SANBORN@sakilacustomer.org', 'GE*****.org'),
#  ('MARC.OUTLAW@sakilacustomer.org', 'MA*****.org'),
#  ('REGINALD.KINDER@sakilacustomer.org', 'RE*****.org'),
#  ('RUBEN.GEARY@sakilacustomer.org', 'RU*****.org'),
#  ('BRETT.CORNWELL@sakilacustomer.org', 'BR*****.org'),
#  ('ANGEL.BARCLAY@sakilacustomer.org', 'AN*****.org'),
#  ('NATHANIEL.ADAM@sakilacustomer.org', 'NA*****.org'),
#  ('RAFAEL.ABNEY@sakilacustomer.org', 'RA*****.org'),
#  ('LESLIE.SEWARD@sakilacustomer.org', 'LE*****.org'),
#  ('EDGAR.RHOADS@sakilacustomer.org', 'ED*****.org'),
#  ('MILTON.HOWLAND@sakilacustomer.org', 'MI*****.org'),
#  ('RAUL.FORTIER@sakilacustomer.org', 'RA*****.org'),
#  ('CHESTER.BENNER@sakilacustomer.org', 'CH*****.org'),
#  ('CECIL.VINES@sakilacustomer.org', 'CE*****.org'),
#  ('DUANE.TUBBS@sakilacustomer.org', 'DU*****.org'),
#  ('FRANKLIN.TROUTMAN@sakilacustomer.org', 'FR*****.org'),
#  ('ANDRE.RAPP@sakilacustomer.org', 'AN*****.org'),
#  ('ELMER.NOE@sakilacustomer.org', 'EL*****.org'),
#  ('BRAD.MCCURDY@sakilacustomer.org', 'BR*****.org'),
#  ('GABRIEL.HARDER@sakilacustomer.org', 'GA*****.org'),
#  ('RON.DELUCA@sakilacustomer.org', 'RO*****.org'),
#  ('MITCHELL.WESTMORELAND@sakilacustomer.org', 'MI*****.org'),
#  ('ROLAND.SOUTH@sakilacustomer.org', 'RO*****.org'),
#  ('ARNOLD.HAVENS@sakilacustomer.org', 'AR*****.org'),
#  ('HARVEY.GUAJARDO@sakilacustomer.org', 'HA*****.org'),
#  ('JARED.ELY@sakilacustomer.org', 'JA*****.org'),
#  ('ADRIAN.CLARY@sakilacustomer.org', 'AD*****.org'),
#  ('KARL.SEAL@sakilacustomer.org', 'KA*****.org'),
#  ('CORY.MEEHAN@sakilacustomer.org', 'CO*****.org'),
#  ('CLAUDE.HERZOG@sakilacustomer.org', 'CL*****.org'),
#  ('ERIK.GUILLEN@sakilacustomer.org', 'ER*****.org'),
#  ('DARRYL.ASHCRAFT@sakilacustomer.org', 'DA*****.org'),
#  ('JAMIE.WAUGH@sakilacustomer.org', 'JA*****.org'),
#  ('NEIL.RENNER@sakilacustomer.org', 'NE*****.org'),
#  ('JESSIE.MILAM@sakilacustomer.org', 'JE*****.org'),
#  ('JAVIER.ELROD@sakilacustomer.org', 'JA*****.org'),
#  ('FERNANDO.CHURCHILL@sakilacustomer.org', 'FE*****.org'),
#  ('CLINTON.BUFORD@sakilacustomer.org', 'CL*****.org'),
#  ('TED.BREAUX@sakilacustomer.org', 'TE*****.org'),
#  ('MATHEW.BOLIN@sakilacustomer.org', 'MA*****.org'),
#  ('TYRONE.ASHER@sakilacustomer.org', 'TY*****.org'),
#  ('DARREN.WINDHAM@sakilacustomer.org', 'DA*****.org'),
#  ('LONNIE.TIRADO@sakilacustomer.org', 'LO*****.org'),
#  ('LANCE.PEMBERTON@sakilacustomer.org', 'LA*****.org'),
#  ('CODY.NOLEN@sakilacustomer.org', 'CO*****.org'),
#  ('JULIO.NOLAND@sakilacustomer.org', 'JU*****.org'),
#  ('KELLY.KNOTT@sakilacustomer.org', 'KE*****.org'),
#  ('KURT.EMMONS@sakilacustomer.org', 'KU*****.org'),
#  ('ALLAN.CORNISH@sakilacustomer.org', 'AL*****.org'),
#  ('NELSON.CHRISTENSON@sakilacustomer.org', 'NE*****.org'),
#  ('GUY.BROWNLEE@sakilacustomer.org', 'GU*****.org'),
#  ('CLAYTON.BARBEE@sakilacustomer.org', 'CL*****.org'),
#  ('HUGH.WALDROP@sakilacustomer.org', 'HU*****.org'),
#  ('MAX.PITT@sakilacustomer.org', 'MA*****.org'),
#  ('DWAYNE.OLVERA@sakilacustomer.org', 'DW*****.org'),
#  ('DWIGHT.LOMBARDI@sakilacustomer.org', 'DW*****.org'),
#  ('ARMANDO.GRUBER@sakilacustomer.org', 'AR*****.org'),
#  ('FELIX.GAFFNEY@sakilacustomer.org', 'FE*****.org'),
#  ('EVERETT.BANDA@sakilacustomer.org', 'EV*****.org'),
#  ('JORDAN.ARCHULETA@sakilacustomer.org', 'JO*****.org'),
#  ('IAN.STILL@sakilacustomer.org', 'IA*****.org'),
#  ('WALLACE.SLONE@sakilacustomer.org', 'WA*****.org'),
#  ('KEN.PREWITT@sakilacustomer.org', 'KE*****.org'),
#  ('BOB.PFEIFFER@sakilacustomer.org', 'BO*****.org'),
#  ('JAIME.NETTLES@sakilacustomer.org', 'JA*****.org'),
#  ('CASEY.MENA@sakilacustomer.org', 'CA*****.org'),
#  ('ALFREDO.MCADAMS@sakilacustomer.org', 'AL*****.org'),
#  ('ALBERTO.HENNING@sakilacustomer.org', 'AL*****.org'),
#  ('DAVE.GARDINER@sakilacustomer.org', 'DA*****.org'),
#  ('IVAN.CROMWELL@sakilacustomer.org', 'IV*****.org'),
#  ('JOHNNIE.CHISHOLM@sakilacustomer.org', 'JO*****.org'),
#  ('SIDNEY.BURLESON@sakilacustomer.org', 'SI*****.org'),
#  ('BYRON.BOX@sakilacustomer.org', 'BY*****.org'),
#  ('JULIAN.VEST@sakilacustomer.org', 'JU*****.org'),
#  ('ISAAC.OGLESBY@sakilacustomer.org', 'IS*****.org'),
#  ('MORRIS.MCCARTER@sakilacustomer.org', 'MO*****.org'),
#  ('CLIFTON.MALCOLM@sakilacustomer.org', 'CL*****.org'),
#  ('WILLARD.LUMPKIN@sakilacustomer.org', 'WI*****.org'),
#  ('DARYL.LARUE@sakilacustomer.org', 'DA*****.org'),
#  ('ROSS.GREY@sakilacustomer.org', 'RO*****.org'),
#  ('VIRGIL.WOFFORD@sakilacustomer.org', 'VI*****.org'),
#  ('ANDY.VANHORN@sakilacustomer.org', 'AN*****.org'),
#  ('MARSHALL.THORN@sakilacustomer.org', 'MA*****.org'),
#  ('SALVADOR.TEEL@sakilacustomer.org', 'SA*****.org'),
#  ('PERRY.SWAFFORD@sakilacustomer.org', 'PE*****.org'),
#  ('KIRK.STCLAIR@sakilacustomer.org', 'KI*****.org'),
#  ('SERGIO.STANFIELD@sakilacustomer.org', 'SE*****.org'),
#  ('MARION.OCAMPO@sakilacustomer.org', 'MA*****.org'),
#  ('TRACY.HERRMANN@sakilacustomer.org', 'TR*****.org'),
#  ('SETH.HANNON@sakilacustomer.org', 'SE*****.org'),
#  ('KENT.ARSENAULT@sakilacustomer.org', 'KE*****.org'),
#  ('RENE.MCALISTER@sakilacustomer.org', 'RE*****.org'),
#  ('EDUARDO.HIATT@sakilacustomer.org', 'ED*****.org'),
#  ('TERRENCE.GUNDERSON@sakilacustomer.org', 'TE*****.org'),
#  ('ENRIQUE.FORSYTHE@sakilacustomer.org', 'EN*****.org'),
#  ('FREDDIE.DUGGAN@sakilacustomer.org', 'FR*****.org'),
#  ('WADE.DELVALLE@sakilacustomer.org', 'WA*****.org'),
#  ('AUSTIN.CINTRON@sakilacustomer.org', 'AU*****.org')]

# %% [markdown]
# ### 3. Conceal complexity
# Not only can you hide unnecessary columns that may confuse a user, especially a non-technical user, you can remove the need to perform JOINs.
#
# Create a VIEW to find actors for a specific category. Have the ability to return the film title.
# Tables?
# - film
# - film_actor
# - actor
# - film_category
# - category
# Moving forward use the ```CREATE OR REPLACE``` syntax for convenience.

# %%
# %%sql
# CREATE OR REPLACE VIEW film_actor_genre AS
#     SELECT first_name,
#         last_name,
#         name AS film_genre,
#         title
#     FROM film f
#     JOIN film_actor fa
#         ON f.film_id = fa.film_id
#     JOIN actor a
#         ON fa.actor_id = a.actor_id
#     JOIN film_category fc
#         ON f.film_id = fc.film_id
#     JOIN category c
#         ON fc.category_id = c.category_id;
# Out:
#  * mysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/sakila
# 0 rows affected.
# []

# %% [markdown]
# Verify the view by creating a list of comedy actors.

# %%
# %%sql
# SELECT *
# FROM film_actor_genre
# WHERE film_genre = 'comedy';
# Out:
#  * mysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/sakila
# 286 rows affected.
# [('JIM', 'MOSTEL', 'Comedy', 'AIRPLANE SIERRA'),
#  ('RICHARD', 'PENN', 'Comedy', 'AIRPLANE SIERRA'),
#  ('OPRAH', 'KILMER', 'Comedy', 'AIRPLANE SIERRA'),
#  ('MENA', 'HOPPER', 'Comedy', 'AIRPLANE SIERRA'),
#  ('MICHAEL', 'BOLGER', 'Comedy', 'AIRPLANE SIERRA'),
#  ('MILLA', 'KEITEL', 'Comedy', 'ANTHEM LUKE'),
#  ('OPRAH', 'KILMER', 'Comedy', 'ANTHEM LUKE'),
#  ('FRANCES', 'DAY-LEWIS', 'Comedy', 'BRINGING HYSTERICAL'),
#  ('ANGELA', 'WITHERSPOON', 'Comedy', 'BRINGING HYSTERICAL'),
#  ('HELEN', 'VOIGHT', 'Comedy', 'CAPER MOTIONS'),
#  ('AUDREY', 'OLIVIER', 'Comedy', 'CAPER MOTIONS'),
#  ('VAL', 'BOLGER', 'Comedy', 'CAPER MOTIONS'),
#  ('CHRISTIAN', 'AKROYD', 'Comedy', 'CAPER MOTIONS'),
#  ('KEVIN', 'GARLAND', 'Comedy', 'CAPER MOTIONS'),
#  ('CATE', 'MCQUEEN', 'Comedy', 'CAPER MOTIONS'),
#  ('BURT', 'TEMPLE', 'Comedy', 'CAPER MOTIONS'),
#  ('HELEN', 'VOIGHT', 'Comedy', 'CAT CONEHEADS'),
#  ('ANGELA', 'WITHERSPOON', 'Comedy', 'CAT CONEHEADS'),
#  ('LAURA', 'BRODY', 'Comedy', 'CAT CONEHEADS'),
#  ('RENEE', 'BALL', 'Comedy', 'CAT CONEHEADS'),
#  ('KIRSTEN', 'PALTROW', 'Comedy', 'CLOSER BANG'),
#  ('JODIE', 'DEGENERES', 'Comedy', 'CLOSER BANG'),
#  ('RUSSELL', 'TEMPLE', 'Comedy', 'CLOSER BANG'),
#  ('GRETA', 'MALDEN', 'Comedy', 'CLOSER BANG'),
#  ('ED', 'GUINESS', 'Comedy', 'CLOSER BANG'),
#  ('JULIA', 'FAWCETT', 'Comedy', 'CLOSER BANG'),
#  ('CAMERON', 'STREEP', 'Comedy', 'CONNECTION MICROCOSMOS'),
#  ('NATALIE', 'HOPKINS', 'Comedy', 'CONNECTION MICROCOSMOS'),
#  ('SCARLETT', 'DAMON', 'Comedy', 'CONNECTION MICROCOSMOS'),
#  ('RENEE', 'TRACY', 'Comedy', 'CONNECTION MICROCOSMOS'),
#  ('FAY', 'WINSLET', 'Comedy', 'CONNECTION MICROCOSMOS'),
#  ('RUSSELL', 'TEMPLE', 'Comedy', 'CONNECTION MICROCOSMOS'),
#  ('VIVIEN', 'BASINGER', 'Comedy', 'CONNECTION MICROCOSMOS'),
#  ('BOB', 'FAWCETT', 'Comedy', 'CONTROL ANTHEM'),
#  ('AUDREY', 'OLIVIER', 'Comedy', 'CONTROL ANTHEM'),
#  ('CHARLIZE', 'DENCH', 'Comedy', 'CONTROL ANTHEM'),
#  ('SISSY', 'SOBIESKI', 'Comedy', 'CRAZY HOME'),
#  ('WOODY', 'JOLIE', 'Comedy', 'CRAZY HOME'),
#  ('MEG', 'HAWKE', 'Comedy', 'CRAZY HOME'),
#  ('RUSSELL', 'BACALL', 'Comedy', 'CRAZY HOME'),
#  ('MORGAN', 'MCDORMAND', 'Comedy', 'CRAZY HOME'),
#  ('ALBERT', 'NOLTE', 'Comedy', 'CRAZY HOME'),
#  ('CATE', 'HARRIS', 'Comedy', 'CRAZY HOME'),
#  ('RUSSELL', 'TEMPLE', 'Comedy', 'CRAZY HOME'),
#  ('VIVIEN', 'BASINGER', 'Comedy', 'CRAZY HOME'),
#  ('HARVEY', 'HOPE', 'Comedy', 'CRAZY HOME'),
#  ('WILL', 'WILSON', 'Comedy', 'CRAZY HOME'),
#  ('ALAN', 'DREYFUSS', 'Comedy', 'CRAZY HOME'),
#  ('GENE', 'MCKELLEN', 'Comedy', 'CRAZY HOME'),
#  ('JOHNNY', 'LOLLOBRIGIDA', 'Comedy', 'DADDY PITTSBURGH'),
#  ('KENNETH', 'PALTROW', 'Comedy', 'DADDY PITTSBURGH'),
#  ('MICHELLE', 'MCCONAUGHEY', 'Comedy', 'DADDY PITTSBURGH'),
#  ('KEVIN', 'GARLAND', 'Comedy', 'DADDY PITTSBURGH'),
#  ('DARYL', 'CRAWFORD', 'Comedy', 'DADDY PITTSBURGH'),
#  ('CAMERON', 'STREEP', 'Comedy', 'DOOM DANCING'),
#  ('NICK', 'STALLONE', 'Comedy', 'DOOM DANCING'),
#  ('CHRISTIAN', 'AKROYD', 'Comedy', 'DOOM DANCING'),
#  ('JESSICA', 'BAILEY', 'Comedy', 'DOOM DANCING'),
#  ('MAE', 'HOFFMAN', 'Comedy', 'DOOM DANCING'),
#  ('WOODY', 'JOLIE', 'Comedy', 'DOOM DANCING'),
#  ('WARREN', 'NOLTE', 'Comedy', 'DOOM DANCING'),
#  ('CHRIS', 'DEPP', 'Comedy', 'DOOM DANCING'),
#  ('WOODY', 'JOLIE', 'Comedy', 'DOWNHILL ENOUGH'),
#  ('BEN', 'WILLIS', 'Comedy', 'DOWNHILL ENOUGH'),
#  ('DARYL', 'CRAWFORD', 'Comedy', 'DOWNHILL ENOUGH'),
#  ('HARVEY', 'HOPE', 'Comedy', 'DOWNHILL ENOUGH'),
#  ('GROUCHO', 'SINATRA', 'Comedy', 'DYING MAKER'),
#  ('MICHAEL', 'BOLGER', 'Comedy', 'DYING MAKER'),
#  ('KIRK', 'JOVOVICH', 'Comedy', 'ELEMENT FREDDY'),
#  ('ANGELA', 'HUDSON', 'Comedy', 'ELEMENT FREDDY'),
#  ('MERYL', 'GIBSON', 'Comedy', 'ELEMENT FREDDY'),
#  ('BELA', 'WALKEN', 'Comedy', 'ELEMENT FREDDY'),
#  ('SISSY', 'SOBIESKI', 'Comedy', 'FERRIS MOTHER'),
#  ('VAL', 'BOLGER', 'Comedy', 'FIREBALL PHILADELPHIA'),
#  ('JUDE', 'CRUISE', 'Comedy', 'FIREBALL PHILADELPHIA'),
#  ('ADAM', 'GRANT', 'Comedy', 'FIREBALL PHILADELPHIA'),
#  ('JAMES', 'PITT', 'Comedy', 'FIREBALL PHILADELPHIA'),
#  ('FRANCES', 'TOMEI', 'Comedy', 'FIREBALL PHILADELPHIA'),
#  ('ALBERT', 'NOLTE', 'Comedy', 'FLINTSTONES HAPPINESS'),
#  ('HUMPHREY', 'WILLIS', 'Comedy', 'FLINTSTONES HAPPINESS'),
#  ('DEBBIE', 'AKROYD', 'Comedy', 'FLINTSTONES HAPPINESS'),
#  ('BELA', 'WALKEN', 'Comedy', 'FLINTSTONES HAPPINESS'),
#  ('SCARLETT', 'DAMON', 'Comedy', 'FRANKENSTEIN STRANGER'),
#  ('BEN', 'HARRIS', 'Comedy', 'FRANKENSTEIN STRANGER'),
#  ('CAMERON', 'STREEP', 'Comedy', 'FREEDOM CLEOPATRA'),
#  ('ALEC', 'WAYNE', 'Comedy', 'FREEDOM CLEOPATRA'),
#  ('TOM', 'MCKELLEN', 'Comedy', 'FREEDOM CLEOPATRA'),
#  ('RAY', 'JOHANSSON', 'Comedy', 'FREEDOM CLEOPATRA'),
#  ('CHRISTOPHER', 'BERRY', 'Comedy', 'FREEDOM CLEOPATRA'),
#  ('GROUCHO', 'DUNST', 'Comedy', 'GOLD RIVER'),
#  ('RUSSELL', 'TEMPLE', 'Comedy', 'GOLD RIVER'),
#  ('UMA', 'WOOD', 'Comedy', 'GROUNDHOG UNCUT'),
#  ('JULIA', 'BARRYMORE', 'Comedy', 'GROUNDHOG UNCUT'),
#  ('JAYNE', 'NEESON', 'Comedy', 'GROUNDHOG UNCUT'),
#  ('ADAM', 'GRANT', 'Comedy', 'GROUNDHOG UNCUT'),
#  ('SEAN', 'GUINESS', 'Comedy', 'GROUNDHOG UNCUT'),
#  ('RICHARD', 'PENN', 'Comedy', 'GROUNDHOG UNCUT'),
#  ('GROUCHO', 'WILLIAMS', 'Comedy', 'GROUNDHOG UNCUT'),
#  ('CARMEN', 'HUNT', 'Comedy', 'GUNFIGHT MOON'),
#  ('GINA', 'DEGENERES', 'Comedy', 'GUNFIGHT MOON'),
#  ('KEVIN', 'GARLAND', 'Comedy', 'GUNFIGHT MOON'),
#  ('RUSSELL', 'CLOSE', 'Comedy', 'GUNFIGHT MOON'),
#  ('BOB', 'FAWCETT', 'Comedy', 'HATE HANDICAP'),
#  ('KEVIN', 'BLOOM', 'Comedy', 'HATE HANDICAP'),
#  ('RIVER', 'DEAN', 'Comedy', 'HATE HANDICAP'),
#  ('BURT', 'DUKAKIS', 'Comedy', 'HEAVEN FREEDOM'),
#  ('KIRK', 'JOVOVICH', 'Comedy', 'HEAVEN FREEDOM'),
#  ('CHARLIZE', 'DENCH', 'Comedy', 'HEAVEN FREEDOM'),
#  ('ADAM', 'HOPPER', 'Comedy', 'HEAVEN FREEDOM'),
#  ('RICHARD', 'PENN', 'Comedy', 'HEAVEN FREEDOM'),
#  ('MORGAN', 'WILLIAMS', 'Comedy', 'HEAVEN FREEDOM'),
#  ('ALBERT', 'JOHANSSON', 'Comedy', 'HEAVEN FREEDOM'),
#  ('FAY', 'WINSLET', 'Comedy', 'HEAVEN FREEDOM'),
#  ('OPRAH', 'KILMER', 'Comedy', 'HEAVEN FREEDOM'),
#  ('GREGORY', 'GOODING', 'Comedy', 'HEAVEN FREEDOM'),
#  ('JAYNE', 'NEESON', 'Comedy', 'HEDWIG ALTER'),
#  ('JAMES', 'PITT', 'Comedy', 'HEDWIG ALTER'),
#  ('GENE', 'HOPKINS', 'Comedy', 'HEDWIG ALTER'),
#  ('DEBBIE', 'AKROYD', 'Comedy', 'HEDWIG ALTER'),
#  ('KIRSTEN', 'AKROYD', 'Comedy', 'HURRICANE AFFAIR'),
#  ('RUSSELL', 'BACALL', 'Comedy', 'HURRICANE AFFAIR'),
#  ('FAY', 'WINSLET', 'Comedy', 'HURRICANE AFFAIR'),
#  ('ALEC', 'WAYNE', 'Comedy', 'HUSTLER PARTY'),
#  ('ANGELINA', 'ASTAIRE', 'Comedy', 'HUSTLER PARTY'),
#  ('MINNIE', 'KILMER', 'Comedy', 'HUSTLER PARTY'),
#  ('CHRISTOPHER', 'WEST', 'Comedy', 'HUSTLER PARTY'),
#  ('HELEN', 'VOIGHT', 'Comedy', 'JAWS HARRY'),
#  ('LUCILLE', 'TRACY', 'Comedy', 'JAWS HARRY'),
#  ('PARKER', 'GOLDBERG', 'Comedy', 'JAWS HARRY'),
#  ('MINNIE', 'ZELLWEGER', 'Comedy', 'JAWS HARRY'),
#  ('GRETA', 'KEITEL', 'Comedy', 'JAWS HARRY'),
#  ('CUBA', 'OLIVIER', 'Comedy', 'KNOCK WARLOCK'),
#  ('WOODY', 'HOFFMAN', 'Comedy', 'KNOCK WARLOCK'),
#  ('AUDREY', 'OLIVIER', 'Comedy', 'KNOCK WARLOCK'),
#  ('TOM', 'MIRANDA', 'Comedy', 'KNOCK WARLOCK'),
#  ('REESE', 'KILMER', 'Comedy', 'KNOCK WARLOCK'),
#  ('JUDE', 'CRUISE', 'Comedy', 'KNOCK WARLOCK'),
#  ('CHRISTIAN', 'GABLE', 'Comedy', 'LIFE TWISTED'),
#  ('UMA', 'WOOD', 'Comedy', 'LIFE TWISTED'),
#  ('MINNIE', 'ZELLWEGER', 'Comedy', 'LIFE TWISTED'),
#  ('DARYL', 'WAHLBERG', 'Comedy', 'LIFE TWISTED'),
#  ('CHRISTOPHER', 'WEST', 'Comedy', 'LIFE TWISTED'),
#  ('GENE', 'MCKELLEN', 'Comedy', 'LIFE TWISTED'),
#  ('MATTHEW', 'CARREY', 'Comedy', 'LIFE TWISTED'),
#  ('REESE', 'WEST', 'Comedy', 'LIFE TWISTED'),
#  ('UMA', 'WOOD', 'Comedy', 'LION UNCUT'),
#  ('PENELOPE', 'PINKETT', 'Comedy', 'LION UNCUT'),
#  ('BELA', 'WALKEN', 'Comedy', 'LION UNCUT'),
#  ('RIP', 'CRAWFORD', 'Comedy', 'LONELY ELEPHANT'),
#  ('VAL', 'BOLGER', 'Comedy', 'LONELY ELEPHANT'),
#  ('KENNETH', 'PALTROW', 'Comedy', 'LONELY ELEPHANT'),
#  ('BEN', 'WILLIS', 'Comedy', 'LONELY ELEPHANT'),
#  ('JAMES', 'PITT', 'Comedy', 'LONELY ELEPHANT'),
#  ('CHARLIZE', 'DENCH', 'Comedy', 'LONELY ELEPHANT'),
#  ('SEAN', 'GUINESS', 'Comedy', 'LONELY ELEPHANT'),
#  ('WALTER', 'TORN', 'Comedy', 'LONELY ELEPHANT'),
#  ('EWAN', 'GOODING', 'Comedy', 'LONELY ELEPHANT'),
#  ('GROUCHO', 'WILLIAMS', 'Comedy', 'LONELY ELEPHANT'),
#  ('ALAN', 'DREYFUSS', 'Comedy', 'LONELY ELEPHANT'),
#  ('ROCK', 'DUKAKIS', 'Comedy', 'LONELY ELEPHANT'),
#  ('NICK', 'WAHLBERG', 'Comedy', 'MALLRATS UNITED'),
#  ('VAL', 'BOLGER', 'Comedy', 'MALLRATS UNITED'),
#  ('CAMERON', 'ZELLWEGER', 'Comedy', 'MALLRATS UNITED'),
#  ('VIVIEN', 'BASINGER', 'Comedy', 'MALLRATS UNITED'),
#  ('MARY', 'KEITEL', 'Comedy', 'MALLRATS UNITED'),
#  ('TOM', 'MIRANDA', 'Comedy', 'MEMENTO ZOOLANDER'),
#  ('ANGELINA', 'ASTAIRE', 'Comedy', 'MEMENTO ZOOLANDER'),
#  ('KIRSTEN', 'AKROYD', 'Comedy', 'MEMENTO ZOOLANDER'),
#  ('SUSAN', 'DAVIS', 'Comedy', 'MEMENTO ZOOLANDER'),
#  ('ALBERT', 'NOLTE', 'Comedy', 'MEMENTO ZOOLANDER'),
#  ('MARY', 'KEITEL', 'Comedy', 'MEMENTO ZOOLANDER'),
#  ('NICK', 'STALLONE', 'Comedy', 'MULAN MOON'),
#  ('ANGELINA', 'ASTAIRE', 'Comedy', 'MULAN MOON'),
#  ('GRETA', 'MALDEN', 'Comedy', 'MULAN MOON'),
#  ('MATTHEW', 'CARREY', 'Comedy', 'MULAN MOON'),
#  ('JULIA', 'FAWCETT', 'Comedy', 'MULAN MOON'),
#  ('SCARLETT', 'DAMON', 'Comedy', 'MYSTIC TRUMAN'),
#  ('KEVIN', 'GARLAND', 'Comedy', 'MYSTIC TRUMAN'),
#  ('RIVER', 'DEAN', 'Comedy', 'MYSTIC TRUMAN'),
#  ('HUMPHREY', 'WILLIS', 'Comedy', 'MYSTIC TRUMAN'),
#  ('CHRISTIAN', 'AKROYD', 'Comedy', 'OPERATION OPERATION'),
#  ('ADAM', 'GRANT', 'Comedy', 'OPERATION OPERATION'),
#  ('GREGORY', 'GOODING', 'Comedy', 'OPERATION OPERATION'),
#  ('JODIE', 'DEGENERES', 'Comedy', 'PARADISE SABRINA'),
#  ('PENELOPE', 'CRONYN', 'Comedy', 'PARADISE SABRINA'),
#  ('SYLVESTER', 'DERN', 'Comedy', 'PARADISE SABRINA'),
#  ('JEFF', 'SILVERSTONE', 'Comedy', 'PARADISE SABRINA'),
#  ('RIVER', 'DEAN', 'Comedy', 'PARTY KNOCK'),
#  ('CHRIS', 'DEPP', 'Comedy', 'PARTY KNOCK'),
#  ('KARL', 'BERRY', 'Comedy', 'PERFECT GROOVE'),
#  ('NATALIE', 'HOPKINS', 'Comedy', 'PERFECT GROOVE'),
#  ('BEN', 'WILLIS', 'Comedy', 'PERFECT GROOVE'),
#  ('JIM', 'MOSTEL', 'Comedy', 'PERFECT GROOVE'),
#  ('JAYNE', 'NOLTE', 'Comedy', 'PERFECT GROOVE'),
#  ('LAURENCE', 'BULLOCK', 'Comedy', 'PERFECT GROOVE'),
#  ('KIRSTEN', 'PALTROW', 'Comedy', 'PINOCCHIO SIMON'),
#  ('REESE', 'KILMER', 'Comedy', 'PINOCCHIO SIMON'),
#  ('RALPH', 'CRUZ', 'Comedy', 'PINOCCHIO SIMON'),
#  ('ELLEN', 'PRESLEY', 'Comedy', 'PINOCCHIO SIMON'),
#  ('CAMERON', 'ZELLWEGER', 'Comedy', 'PINOCCHIO SIMON'),
#  ('MORGAN', 'HOPKINS', 'Comedy', 'PINOCCHIO SIMON'),
#  ('RIVER', 'DEAN', 'Comedy', 'PINOCCHIO SIMON'),
#  ('BEN', 'HARRIS', 'Comedy', 'PINOCCHIO SIMON'),
#  ('MERYL', 'GIBSON', 'Comedy', 'PINOCCHIO SIMON'),
#  ('LAURA', 'BRODY', 'Comedy', 'PINOCCHIO SIMON'),
#  ('JOHN', 'SUVARI', 'Comedy', 'PINOCCHIO SIMON'),
#  ('CAMERON', 'STREEP', 'Comedy', 'PURE RUNNER'),
#  ('MILLA', 'KEITEL', 'Comedy', 'PURE RUNNER'),
#  ('NICK', 'WAHLBERG', 'Comedy', 'RUSHMORE MERMAID'),
#  ('MILLA', 'PECK', 'Comedy', 'RUSHMORE MERMAID'),
#  ('JOHNNY', 'CAGE', 'Comedy', 'RUSHMORE MERMAID'),
#  ('PENELOPE', 'PINKETT', 'Comedy', 'RUSHMORE MERMAID'),
#  ('HENRY', 'BERRY', 'Comedy', 'RUSHMORE MERMAID'),
#  ('HARRISON', 'BALE', 'Comedy', 'RUSHMORE MERMAID'),
#  ('FAY', 'WOOD', 'Comedy', 'RUSHMORE MERMAID'),
#  ('BOB', 'FAWCETT', 'Comedy', 'SADDLE ANTITRUST'),
#  ('ADAM', 'HOPPER', 'Comedy', 'SADDLE ANTITRUST'),
#  ('MINNIE', 'KILMER', 'Comedy', 'SADDLE ANTITRUST'),
#  ('ANGELINA', 'ASTAIRE', 'Comedy', 'SATURN NAME'),
#  ('CHRIS', 'BRIDGES', 'Comedy', 'SATURN NAME'),
#  ('SUSAN', 'DAVIS', 'Comedy', 'SEARCHERS WAIT'),
#  ('GINA', 'DEGENERES', 'Comedy', 'SEARCHERS WAIT'),
#  ('CATE', 'MCQUEEN', 'Comedy', 'SEARCHERS WAIT'),
#  ('ROCK', 'DUKAKIS', 'Comedy', 'SEARCHERS WAIT'),
#  ('SCARLETT', 'BENING', 'Comedy', 'SNATCH SLIPPER'),
#  ('CATE', 'MCQUEEN', 'Comedy', 'SNATCH SLIPPER'),
#  ('RITA', 'REYNOLDS', 'Comedy', 'SNATCH SLIPPER'),
#  ('WALTER', 'TORN', 'Comedy', 'STAGE WORLD'),
#  ('BELA', 'WALKEN', 'Comedy', 'STAGE WORLD'),
#  ('GREG', 'CHAPLIN', 'Comedy', 'STRICTLY SCARFACE'),
#  ('DARYL', 'CRAWFORD', 'Comedy', 'STRICTLY SCARFACE'),
#  ('WHOOPI', 'HURT', 'Comedy', 'STRICTLY SCARFACE'),
#  ('ALAN', 'DREYFUSS', 'Comedy', 'STRICTLY SCARFACE'),
#  ('JENNIFER', 'DAVIS', 'Comedy', 'SUBMARINE BED'),
#  ('PENELOPE', 'PINKETT', 'Comedy', 'SUBMARINE BED'),
#  ('CHRISTIAN', 'AKROYD', 'Comedy', 'SUBMARINE BED'),
#  ('RALPH', 'CRUZ', 'Comedy', 'SUBMARINE BED'),
#  ('SEAN', 'GUINESS', 'Comedy', 'SUBMARINE BED'),
#  ('SIDNEY', 'CROWE', 'Comedy', 'SUBMARINE BED'),
#  ('GROUCHO', 'DUNST', 'Comedy', 'SUBMARINE BED'),
#  ('WARREN', 'JACKMAN', 'Comedy', 'SUBMARINE BED'),
#  ('SCARLETT', 'BENING', 'Comedy', 'SUBMARINE BED'),
#  ('GREGORY', 'GOODING', 'Comedy', 'SUBMARINE BED'),
#  ('MARY', 'KEITEL', 'Comedy', 'SUBMARINE BED'),
#  ('KARL', 'BERRY', 'Comedy', 'SWEDEN SHINING'),
#  ('KEVIN', 'BLOOM', 'Comedy', 'SWEDEN SHINING'),
#  ('MARY', 'TANDY', 'Comedy', 'SWEDEN SHINING'),
#  ('ALBERT', 'JOHANSSON', 'Comedy', 'SWEDEN SHINING'),
#  ('MARY', 'KEITEL', 'Comedy', 'SWEDEN SHINING'),
#  ('GREG', 'CHAPLIN', 'Comedy', 'TRAINSPOTTING STRANGERS'),
#  ('GINA', 'DEGENERES', 'Comedy', 'TRAINSPOTTING STRANGERS'),
#  ('RITA', 'REYNOLDS', 'Comedy', 'TRAINSPOTTING STRANGERS'),
#  ('RUSSELL', 'TEMPLE', 'Comedy', 'TRAINSPOTTING STRANGERS'),
#  ('RIP', 'CRAWFORD', 'Comedy', 'TRAMP OTHERS'),
#  ('SIDNEY', 'CROWE', 'Comedy', 'TRAMP OTHERS'),
#  ('JADA', 'RYDER', 'Comedy', 'TRAMP OTHERS'),
#  ('RIVER', 'DEAN', 'Comedy', 'TRAMP OTHERS'),
#  ('RENEE', 'BALL', 'Comedy', 'TRAMP OTHERS'),
#  ('BELA', 'WALKEN', 'Comedy', 'TRAMP OTHERS'),
#  ('TOM', 'MIRANDA', 'Comedy', 'VALLEY PACKER'),
#  ('CAMERON', 'WRAY', 'Comedy', 'VALLEY PACKER'),
#  ('BEN', 'WILLIS', 'Comedy', 'VALLEY PACKER'),
#  ('SUSAN', 'DAVIS', 'Comedy', 'VALLEY PACKER'),
#  ('ZERO', 'CAGE', 'Comedy', 'VELVET TERMINATOR'),
#  ('JOHNNY', 'CAGE', 'Comedy', 'VELVET TERMINATOR'),
#  ('ANGELA', 'HUDSON', 'Comedy', 'VELVET TERMINATOR'),
#  ('SEAN', 'WILLIAMS', 'Comedy', 'VELVET TERMINATOR'),
#  ('CARY', 'MCCONAUGHEY', 'Comedy', 'VELVET TERMINATOR'),
#  ('CUBA', 'ALLEN', 'Comedy', 'VELVET TERMINATOR'),
#  ('DARYL', 'CRAWFORD', 'Comedy', 'VELVET TERMINATOR'),
#  ('MINNIE', 'KILMER', 'Comedy', 'VELVET TERMINATOR'),
#  ('MERYL', 'ALLEN', 'Comedy', 'VELVET TERMINATOR'),
#  ('PENELOPE', 'GUINESS', 'Comedy', 'VERTIGO NORTHWEST'),
#  ('DAN', 'STREEP', 'Comedy', 'VERTIGO NORTHWEST'),
#  ('WARREN', 'JACKMAN', 'Comedy', 'VERTIGO NORTHWEST'),
#  ('BELA', 'WALKEN', 'Comedy', 'VERTIGO NORTHWEST'),
#  ('SISSY', 'SOBIESKI', 'Comedy', 'WISDOM WORKER'),
#  ('REESE', 'KILMER', 'Comedy', 'WISDOM WORKER'),
#  ('WOODY', 'JOLIE', 'Comedy', 'WISDOM WORKER'),
#  ('JIM', 'MOSTEL', 'Comedy', 'WISDOM WORKER'),
#  ('SUSAN', 'DAVIS', 'Comedy', 'WISDOM WORKER'),
#  ('LAURA', 'BRODY', 'Comedy', 'WISDOM WORKER'),
#  ('WILLIAM', 'HACKMAN', 'Comedy', 'WISDOM WORKER'),
#  ('IAN', 'TANDY', 'Comedy', 'ZORRO ARK'),
#  ('NICK', 'DEGENERES', 'Comedy', 'ZORRO ARK'),
#  ('LISA', 'MONROE', 'Comedy', 'ZORRO ARK')]

# %% [markdown]
# ### 4. Data aggregation
# Many BI applications (Tableau, PowerBI, Looker, Cognos, Domo, Alteryx, SAP, MicroStrategy, etc) query VIEWS and not tables. Analysts normally only have access to VIEWS.
#
# Show the total rental revenue for each film category per month. Results can be used for a monthly report to help managers decide what new films to add to inventory.

# %%
# %%sql
# # month, genre, revenue for month and genre
# CREATE OR REPLACE VIEW sales_by_film_category AS
#     SELECT
#         DATE_FORMAT(rental_date, '%Y-%m') AS rental_month,
#         c.name AS category_name,
#         SUM(p.amount) AS total_rental_revenue
#     FROM rental r
#     JOIN inventory i ON r.inventory_id = i.inventory_id
#     JOIN film f ON i.film_id = f.film_id
#     JOIN film_category fc ON f.film_id = fc.film_id
#     JOIN category c ON fc.category_id = c.category_id
#     JOIN payment p ON r.rental_id = p.rental_id
#     GROUP BY rental_month, category_name;
# Out:
#  * mysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/sakila
# 0 rows affected.
# []

# %% [markdown]
# Validate the VIEW by listing the aggregated rental revenue for August 2005 sorted by the total_rental_revenue.

# %%
# %%sql
# SELECT *
# FROM sales_by_film_category
# WHERE rental_month = '2005-08'
# ORDER BY total_rental_revenue;
# Out:
#  * mysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/sakila
# 16 rows affected.
# [('2005-08', 'Music', Decimal('1163.23')),
#  ('2005-08', 'Travel', Decimal('1244.02')),
#  ('2005-08', 'Children', Decimal('1315.68')),
#  ('2005-08', 'Horror', Decimal('1342.01')),
#  ('2005-08', 'Classics', Decimal('1371.52')),
#  ('2005-08', 'Action', Decimal('1463.16')),
#  ('2005-08', 'Family', Decimal('1474.16')),
#  ('2005-08', 'Games', Decimal('1508.48')),
#  ('2005-08', 'Documentary', Decimal('1517.31')),
#  ('2005-08', 'Drama', Decimal('1526.47')),
#  ('2005-08', 'Comedy', Decimal('1593.58')),
#  ('2005-08', 'Foreign', Decimal('1599.23')),
#  ('2005-08', 'New', Decimal('1626.54')),
#  ('2005-08', 'Animation', Decimal('1654.92')),
#  ('2005-08', 'Sci-Fi', Decimal('1707.15')),
#  ('2005-08', 'Sports', Decimal('1962.68'))]

# %% [markdown]
# ### UPDATE a VIEW
#
# UPDATE the customer last_name for Linda Williams to Kennedy. Directly UPDATE the active_customer VIEW and not the customer table.

# %%
# %%sql
# SELECT *
# FROM active_customer
# WHERE first_name = 'Linda' AND last_name = 'Williams';
#
# UPDATE active_customer
# SET last_name = 'KENNEDY'
# WHERE first_name = 'Linda' AND last_name = 'Kennedy';
# Out:
#  * mysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/sakila
# 0 rows affected.
# 1 rows affected.
# []

# %% [markdown]
# Confirm the change in the active_customer VIEW.

# %%
# %%sql
# SELECT *
# FROM active_customer
# WHERE first_name = 'Linda';
# Out:
#  * mysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/sakila
# 1 rows affected.
# [('LINDA', 'KENNEDY', 'LI*****.org')]

# %% [markdown]
# Confirm the change in the customer table.

# %%
# %%sql
# SELECT *
# FROM customer
# WHERE first_name = 'Linda';
# Out:
#  * mysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/sakila
# 1 rows affected.
# [(3, 1, 'LINDA', 'KENNEDY', 'LINDA.WILLIAMS@sakilacustomer.org', 7, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2023, 3, 6, 19, 22, 9))]
